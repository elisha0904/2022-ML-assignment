# %%
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import combinations

# %% [markdown]
# #### Load data

# %%
X_train = pd.read_csv('X_train_111.csv', encoding='cp949')
y_train = pd.read_csv('y_train.csv', encoding='cp949').Salary

X_test = pd.read_csv('X_test_111.csv', encoding='cp949')
test_id = pd.read_csv('X_test.csv', encoding='cp949').ID

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16570 entries, 0 to 16569
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   직종      16570 non-null  object
#  1   세부직종    16570 non-null  object
#  2   직무태그    16570 non-null  object
#  3   근무경력    16570 non-null  object
#  4   근무형태    16570 non-null  object
#  5   근무지역    16570 non-null  object
#  6   출신대학    16570 non-null  object
#  7   대학전공    16570 non-null  object
#  8   어학시험    16570 non-null  object
#  9   자격증     16570 non-null  object
#  10  대학성적    16570 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.4+ MB

# %% [markdown]
# ***

# %% [markdown]
# # 수치형 피쳐생성

# %% [markdown]
# ### 근무경력 =>수치로 변환해서 '근무개월'열 생성

# %%
### 경력을 수치로 변환
import re

def f1(x):
    numbers = re.findall(r'\d+', x)
    return int(numbers[0])*12 if len(numbers) == 1 else int(numbers[0])*12+int(numbers[1])

X_train['근무개월'] = X_train['근무경력'].apply(f1)
X_test['근무개월'] = X_test['근무경력'].apply(f1)

# %% [markdown]
# ### 근무개월log

# %%
for df in [X_train, X_test]:
    df['근무개월log'] = np.log1p(1+df['근무개월'])

# %% [markdown]
# ### 대학랭킹

# %%
top_rank = ['성균관대학교', '연세대학교', '중앙대학교', '이화여자대학교']
mid_rank = ['세종대학교', '성신여자대학교']
low_rank = ['한성대학교', '동덕여자대학교', '서울여자대학교', '서울과학기술대학교']
province = ['제주대학교', '인천대학교', '군산대학교', '한국산업기술대학교']
etc= ['수원대학교', '전주대학교', '세명대학교', '신라대학교', '상지대학교', '한밭대학교', '경기대학교', '선문대학교', '성공회대학교', '호원대학교', '한림대학교', '목포대학교', '동아대학교', '동의대학교', '성결대학교', '호남대학교', '광주대학교', '서원대학교', '동서대학교', '한일장신대학교', '한세대학교', '용인대학교', '경주대학교', '협성대학교', '서울신학대학교', '송원대학교', '부산디지털대학교','남부대학교','기타']

university = []
for i in X_train['출신대학']:
    if i in top_rank:
        university.append(1)
    elif i in mid_rank:
        university.append(2)
    elif i in low_rank:
        university.append(3)
    elif i in province:
        university.append(4)
    elif i in etc:
        university.append(5)  
        
X_train['대학랭킹'] = university

university = []
for i in X_test['출신대학']:
    if i in top_rank:
        university.append(1)
    elif i in mid_rank:
        university.append(2)
    elif i in low_rank:
        university.append(3)
    elif i in province:
        university.append(4)
    elif i in etc:
        university.append(5)
        
X_test['대학랭킹'] = university

# %% [markdown]
# ### 출신대학수치*대학성적

# %%
university = []
for i in X_train['출신대학']:
    if i in top_rank:
        university.append(5)
    elif i in mid_rank:
        university.append(4)
    elif i in low_rank:
        university.append(3)
    elif i in province:
        university.append(2)
    elif i in etc:
        university.append(1)
        
X_train['출신대학수치'] = university

university = []
for i in X_test['출신대학']:
    if i in top_rank:
        university.append(5)
    elif i in mid_rank:
        university.append(4)
    elif i in low_rank:
        university.append(3)
    elif i in province:
        university.append(2)
    elif i in etc:
        university.append(1) 
        
X_test['출신대학수치'] = university

a = X_train['출신대학수치'] * X_train['대학성적']
X_train['출신대학수치*대학성적'] = a
a = X_test['출신대학수치'] * X_test['대학성적']
X_test['출신대학수치*대학성적'] = a


#출신대학수치 삭제
#X_train = X_train.drop(['출신대학수치'],axis=1)
#X_test = X_test.drop(['출신대학수치'], axis=1)

# %% [markdown]
# ### (범주형) 근무지역 1,2,3으로 나눈 열 생성

# %%
result1=[]
result2=[]
result3=[]

for x in X_train.근무지역:
    L = x.split(',')
    if (L[1]==''):
        result1.append(L[0])
        result2.append(L[0])
        result3.append(L[0])
    elif (L[2]==''):
        result1.append(L[0])
        result2.append(L[1])
        result3.append(L[1])
    else: 
        result1.append(L[0])
        result2.append(L[1])
        result3.append(L[2])
        
X_train['근무지역_1'] = result1
X_train['근무지역_2'] = result2
X_train['근무지역_3'] = result3

# %%
result1=[]
result2=[]
result3=[]

for x in X_test.근무지역:
    L = x.split(',')
    if (L[1]==''):
        result1.append(L[0])
        result2.append(L[0])
        result3.append(L[0])
    elif (L[2]==''):
        result1.append(L[0])
        result2.append(L[1])
        result3.append(L[1])
    else: 
        result1.append(L[0])
        result2.append(L[1])
        result3.append(L[2])
        
X_test['근무지역_1'] = result1
X_test['근무지역_2'] = result2
X_test['근무지역_3'] = result3

# %% [markdown]
# ### (범주형)마지막근무형태

# %%
X_train['마지막근무형태'] = 0
for i in range(0,len(X_train.근무형태),1):
    X_train['마지막근무형태'][i] = X_train.근무형태[i].split(', ')[-1]
    if (X_train.근무형태[i].split(', ')[-1] == ''):
        X_train['마지막근무형태'][i] = X_train.근무형태[i].split(', ')[-2]

X_test['마지막근무형태'] = 0
for i in range(0,len(X_test.근무형태),1):
    X_test['마지막근무형태'][i] = X_test.근무형태[i].split(', ')[-1]
    if (X_test.근무형태[i].split(', ')[-1] == ''):
        X_test['마지막근무형태'][i] = X_test.근무형태[i].split(', ')[-2]

# %% [markdown]
# ### 직무태그 하나씩 열 생성

# %%
List=[]
name = []
for i in range(1,28,1):
    name.append('직무태그_'+ str(i))
    
for n in X_train.직무태그:
    n1 = (n.split(','))
    for i in range(0, len(n1), 1):
        n1[i] = n1[i].strip()
    while(len(n1)<27):
        n1.append(n1[-1])
    List.append(n1)
df1 = pd.DataFrame(List, columns=name)
X_train = pd.concat([X_train,df1],axis=1)

List=[]
name = []
for i in range(1,28,1):
    name.append('직무태그_'+ str(i))
    
for n in X_test.직무태그:
    n1 = (n.split(','))
    for i in range(0, len(n1), 1):
        n1[i] = n1[i].strip()
    while(len(n1)<27):
        n1.append(n1[-1])
    List.append(n1)
df2 = pd.DataFrame(List, columns=name)
X_test = pd.concat([X_test,df2],axis=1)

# %% [markdown]
# ### 직무태그개수

# %%
List = []
for n in X_train.직무태그:
    L = len(n.split(', '))
    List.append(L)
X_train['직무태그개수'] = List

List = []
for n in X_test.직무태그:
    L = len(n.split(', '))
    List.append(L)
X_test['직무태그개수'] = List

# %% [markdown]
# ### 대학성적*0.1 +근무개월

# %%
X_train['대학성적0.1+근무개월'] = X_train.대학성적*0.1 + X_train.근무개월
X_test['대학성적0.1+근무개월'] = X_test.대학성적*0.1 + X_test.근무개월

# %% [markdown]
# ## 범주형 변수 groupby로 수치형 변수 sum, mean, variance, standard deviation 피쳐 생성

# %%
def inf_num(cat, num):
    global X_train
    global X_test
    
    group_object1 = X_train.groupby(by=[cat])[num].agg('sum').reset_index()
    group_object2 = X_test.groupby(by=[cat])[num].agg('sum').reset_index()

    group_object1 = group_object1.rename(columns = {num:(cat+'_'+num+'_sum')})
    group_object2 = group_object2.rename(columns = {num:(cat+'_'+num+'_sum')})

    X_train = pd.merge(X_train, group_object1, on = cat, how='left')
    X_test = pd.merge(X_test, group_object2, on = cat, how='left')

    # mean

    group_object3 = X_train.groupby(by=[cat])[num].agg('mean').reset_index()
    group_object4 = X_test.groupby(by=[cat])[num].agg('mean').reset_index()

    group_object3 = group_object3.rename(columns = {num:(cat+'_'+num+'_mean')})
    group_object4 = group_object4.rename(columns = {num:(cat+'_'+num+'_mean')})

    X_train = pd.merge(X_train, group_object3, on = cat, how='left')
    X_test = pd.merge(X_test, group_object4, on = cat, how='left')

    # variance

    group_object5 = X_train.groupby(by=[cat])[num].agg('var').reset_index()
    group_object6 = X_test.groupby(by=[cat])[num].agg('var').reset_index()

    group_object5 = group_object5.rename(columns = {num:(cat+'_'+num+'_variance')})
    group_object6 = group_object6.rename(columns = {num:(cat+'_'+num+'_variance')})

    X_train = pd.merge(X_train, group_object5, on = cat, how='left')
    X_test = pd.merge(X_test, group_object6, on = cat, how='left')

    # standard deviation

    group_object7 = X_train.groupby(by=[cat])[num].agg('std').reset_index()
    group_object8 = X_test.groupby(by=[cat])[num].agg('std').reset_index()

    group_object7 = group_object7.rename(columns = {num:(cat+'_'+num+'_standard_deviation')})
    group_object8 = group_object8.rename(columns = {num:(cat+'_'+num+'_standard_deviation')})

    X_train = pd.merge(X_train, group_object7, on = cat, how='left')
    X_test = pd.merge(X_test, group_object8, on = cat, how='left')

    X_train[(cat+'_'+num+'_variance')] = X_train[(cat+'_'+num+'_variance')].fillna(0)
    X_test[(cat+'_'+num+'_variance')] = X_test[(cat+'_'+num+'_variance')].fillna(0)
    X_train[(cat+'_'+num+'_standard_deviation')] = X_train[(cat+'_'+num+'_standard_deviation')].fillna(0)
    X_test[(cat+'_'+num+'_standard_deviation')] = X_test[(cat+'_'+num+'_standard_deviation')].fillna(0)

# %%
def inf_num2(cat1,cat2, num):
    global X_train
    global X_test
    
    group_object1 = X_train.groupby(by=[cat1,cat2])[num].agg('sum').reset_index()
    group_object2 = X_test.groupby(by=[cat1,cat2])[num].agg('sum').reset_index()

    group_object1 = group_object1.rename(columns = {num:(cat1+'_'+cat2+'_'+num+'_sum')})
    group_object2 = group_object2.rename(columns = {num:(cat1+'_'+cat2+'_'+num+'_sum')})

    X_train = pd.merge(X_train, group_object1, on = [cat1,cat2], how='left')
    X_test = pd.merge(X_test, group_object2, on = [cat1,cat2], how='left')

    # mean

    group_object3 = X_train.groupby(by=[cat1,cat2])[num].agg('mean').reset_index()
    group_object4 = X_test.groupby(by=[cat1,cat2])[num].agg('mean').reset_index()

    group_object3 = group_object3.rename(columns = {num:(cat1+'_'+cat2+'_'+num+'_mean')})
    group_object4 = group_object4.rename(columns = {num:(cat1+'_'+cat2+'_'+num+'_mean')})

    X_train = pd.merge(X_train, group_object3, on = [cat1,cat2], how='left')
    X_test = pd.merge(X_test, group_object4, on = [cat1,cat2], how='left')

    # variance

    group_object5 = X_train.groupby(by=[cat1,cat2])[num].agg('var').reset_index()
    group_object6 = X_test.groupby(by=[cat1,cat2])[num].agg('var').reset_index()

    group_object5 = group_object5.rename(columns = {num:(cat1+'_'+cat2+'_'+num+'_variance')})
    group_object6 = group_object6.rename(columns = {num:(cat1+'_'+cat2+'_'+num+'_variance')})

    X_train = pd.merge(X_train, group_object5, on = [cat1,cat2], how='left')
    X_test = pd.merge(X_test, group_object6, on = [cat1,cat2], how='left')

    # standard deviation

    group_object7 = X_train.groupby(by=[cat1,cat2])[num].agg('std').reset_index()
    group_object8 = X_test.groupby(by=[cat1,cat2])[num].agg('std').reset_index()

    group_object7 = group_object7.rename(columns = {num:(cat1+'_'+cat2+'_'+num+'_standard_deviation')})
    group_object8 = group_object8.rename(columns = {num:(cat1+'_'+cat2+'_'+num+'_standard_deviation')})

    X_train = pd.merge(X_train, group_object7, on = [cat1,cat2], how='left')
    X_test = pd.merge(X_test, group_object8, on = [cat1,cat2], how='left')

    X_train[(cat1+'_'+cat2+'_'+num+'_variance')] = X_train[(cat1+'_'+cat2+'_'+num+'_variance')].fillna(0)
    X_test[(cat1+'_'+cat2+'_'+num+'_variance')] = X_test[(cat1+'_'+cat2+'_'+num+'_variance')].fillna(0)
    X_train[(cat1+'_'+cat2+'_'+num+'_standard_deviation')] = X_train[(cat1+'_'+cat2+'_'+num+'_standard_deviation')].fillna(0)
    X_test[(cat1+'_'+cat2+'_'+num+'_standard_deviation')] = X_test[(cat1+'_'+cat2+'_'+num+'_standard_deviation')].fillna(0)

# %%
#범주형 변수 하나 별 근무개월
inf_num('출신대학','근무개월')
inf_num('직종','근무개월')
inf_num('세부직종','근무개월')
inf_num('근무지역_1','근무개월')
inf_num('근무지역_2','근무개월')
inf_num('근무지역_3','근무개월')
inf_num('마지막근무형태','근무개월')
inf_num('직무태그_1','근무개월')
inf_num('대학성적','근무개월')
inf_num('대학전공','근무개월')
inf_num('어학시험','근무개월')

#범주형 변수 두개 별 근무개월
inf_num2('직종','세부직종','근무개월')
inf_num2('직종','근무지역_1','근무개월')
inf_num2('직종','근무지역_2','근무개월')
inf_num2('직종','근무지역_3','근무개월')
inf_num2('직종','마지막근무형태','근무개월')
inf_num2('직종','직무태그_1','근무개월')
inf_num2('직종','대학성적','근무개월')

inf_num2('세부직종','근무지역_1','근무개월')
inf_num2('세부직종','근무지역_2','근무개월')
inf_num2('세부직종','근무지역_3','근무개월')
inf_num2('세부직종','마지막근무형태','근무개월')

inf_num2('근무지역_1','근무지역_2','근무개월')
inf_num2('근무지역_1','근무지역_3','근무개월')
inf_num2('근무지역_2','근무지역_3','근무개월')

inf_num2('자격증','어학시험','근무개월')

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16570 entries, 0 to 16569
# Columns: 153 entries, 직종 to 자격증_어학시험_근무개월_standard_deviation
# dtypes: float64(82), int64(30), object(41)
# memory usage: 19.5+ MB

# %% [markdown]
# ### 수치형 변수 통합 열 생성

# %%
X_train['수치형통합'] = np.log1p(1+X_train.근무개월+X_train.대학성적+X_train.출신대학수치)
X_test['수치형통합'] = np.log1p(1+X_test.근무개월+X_test.대학성적+X_test.출신대학수치)

# %%
#범주형 변수 하나 별 근무개월
inf_num('출신대학','수치형통합')
inf_num('직종','수치형통합')
inf_num('세부직종','수치형통합')
inf_num('근무지역_1','수치형통합')
inf_num('근무지역_2','수치형통합')
inf_num('근무지역_3','수치형통합')
inf_num('마지막근무형태','수치형통합')
inf_num('직무태그_1','수치형통합')
inf_num('대학성적','수치형통합')
inf_num('대학전공','수치형통합')
inf_num('어학시험','수치형통합')

#범주형 변수 두개 별 근무개월
inf_num2('직종','세부직종','수치형통합')
inf_num2('직종','근무지역_1','수치형통합')
inf_num2('직종','근무지역_2','수치형통합')
inf_num2('직종','근무지역_3','수치형통합')
inf_num2('직종','마지막근무형태','수치형통합')
inf_num2('직종','직무태그_1','수치형통합')
inf_num2('직종','대학성적','수치형통합')

inf_num2('세부직종','근무지역_1','수치형통합')
inf_num2('세부직종','근무지역_2','수치형통합')
inf_num2('세부직종','근무지역_3','수치형통합')
inf_num2('세부직종','마지막근무형태','수치형통합')

inf_num2('근무지역_1','근무지역_2','수치형통합')
inf_num2('근무지역_1','근무지역_3','수치형통합')
inf_num2('근무지역_2','근무지역_3','수치형통합')

inf_num2('자격증','어학시험','수치형통합')

# %% [markdown]
# # 범주형 피쳐생성

# %% [markdown]
# ### 정규직비정규직
# - 정규직 외 비정규직 처리

# %%
X_train['정규직비정규직'] = np.where(X_train.근무형태 == "정규직", '정규직', '비정규직')
X_test['정규직비정규직'] = np.where(X_test.근무형태 == "정규직", '정규직', '비정규직')

# %% [markdown]
# ### 대학+전공

# %%
X_train['대학+전공'] = X_train['출신대학'] + X_train['대학전공']
X_test['대학+전공'] = X_test['출신대학'] + X_test['대학전공']

# %% [markdown]
# ### 직종+세부직종

# %%
X_train['직종+세부직종']=(X_train.직종 + X_train.세부직종)
X_test['직종+세부직종']=(X_test.직종 + X_test.세부직종)

# %% [markdown]
# ### 근무형태+직종

# %%
X_train['근무형태+직종'] = X_train['근무형태']+X_train['직종']
X_test['근무형태+직종'] = X_test['근무형태']+X_test['직종']

# %% [markdown]
# ### 대학교 인서울 여부

# %%
in_seoul_lst = ['성균관대학교', '중앙대학교', '세종대학교', '연세대학교', '이화여자대학교']

X_train['인서울여부'] = X_train['출신대학'].map(lambda x: '0' if x in in_seoul_lst else '1')

X_test['인서울여부'] = X_test['출신대학'].map(lambda x: '0' if x in in_seoul_lst else '1')

# %% [markdown]
# ### 자격증또는어학시험유무

# %%
X_train['자격증또는어학시험유무'] = np.where((X_train.자격증 == "無")& (X_train.어학시험 == '없음'), 0, 1)
X_test['자격증또는어학시험유무'] = np.where((X_test.자격증 == "無")&(X_test.어학시험 == '없음'), 0, 1)

# %% [markdown]
# ### 범주형 변수 2개 합침

# %%
X_train['직종+직무태그'] = X_train['직종'] + X_train['직무태그']
X_train['직종+근무경력'] = X_train['직종'] + X_train['근무경력']
X_train['직종+대학전공'] = X_train['직종'] + X_train['대학전공']
X_train['직종+어학시험'] = X_train['직종'] + X_train['어학시험']
X_train['직종+자격증'] = X_train['직종'] + X_train['자격증']
#X_train['직종+근무개월'] = X_train['직종'] + X_train['근무개월']
X_train['직종+근무지역_1'] = X_train['직종'] + X_train['근무지역_1']
X_train['직종+근무지역_2'] = X_train['직종'] + X_train['근무지역_2']
X_train['직종+근무지역_3'] = X_train['직종'] + X_train['근무지역_3']
X_train['직종+출신대학'] = X_train['직종'] + X_train['출신대학']
X_train['직종+마지막근무형태'] = X_train['직종'] + X_train['마지막근무형태']

X_test['직종+직무태그'] = X_test['직종'] + X_test['직무태그']
X_test['직종+근무경력'] = X_test['직종'] + X_test['근무경력']
X_test['직종+대학전공'] = X_test['직종'] + X_test['대학전공']
X_test['직종+어학시험'] = X_test['직종'] + X_test['어학시험']
X_test['직종+자격증'] = X_test['직종'] + X_test['자격증']
#X_test['직종+근무개월'] = X_test['직종'] + X_test['근무개월']
X_test['직종+근무지역_1'] = X_test['직종'] + X_test['근무지역_1']
X_test['직종+근무지역_2'] = X_test['직종'] + X_test['근무지역_2']
X_test['직종+근무지역_3'] = X_test['직종'] + X_test['근무지역_3']
X_test['직종+출신대학'] = X_test['직종'] + X_test['출신대학']
X_test['직종+마지막근무형태'] = X_test['직종'] + X_test['마지막근무형태']

X_train['세부직종+직무태그'] = X_train['세부직종'] + X_train['직무태그']
X_train['세부직종+근무경력'] = X_train['세부직종'] + X_train['근무경력']
X_train['세부직종+대학전공'] = X_train['세부직종'] + X_train['대학전공']
X_train['세부직종+어학시험'] = X_train['세부직종'] + X_train['어학시험']
X_train['세부직종+자격증'] = X_train['세부직종'] + X_train['자격증']
#X_train['세부직종+근무개월'] = X_train['세부직종'] + X_train['근무개월']
X_train['세부직종+근무지역_1'] = X_train['세부직종'] + X_train['근무지역_1']
X_train['세부직종+근무지역_2'] = X_train['세부직종'] + X_train['근무지역_2']
X_train['세부직종+근무지역_3'] = X_train['세부직종'] + X_train['근무지역_3']
X_train['세부직종+출신대학'] = X_train['세부직종'] + X_train['출신대학']
X_train['세부직종+근무형태'] = X_train['세부직종'] + X_train['근무형태']
X_train['세부직종+마지막근무형태'] = X_train['세부직종'] + X_train['마지막근무형태']

X_test['세부직종+직무태그'] = X_test['세부직종'] + X_test['직무태그']
X_test['세부직종+근무경력'] = X_test['세부직종'] + X_test['근무경력']
X_test['세부직종+대학전공'] = X_test['세부직종'] + X_test['대학전공']
X_test['세부직종+어학시험'] = X_test['세부직종'] + X_test['어학시험']
X_test['세부직종+자격증'] = X_test['세부직종'] + X_test['자격증']
#X_test['세부직종+근무개월'] = X_test['세부직종'] + X_test['근무개월']
X_test['세부직종+근무지역_1'] = X_test['세부직종'] + X_test['근무지역_1']
X_test['세부직종+근무지역_2'] = X_test['세부직종'] + X_test['근무지역_2']
X_test['세부직종+근무지역_3'] = X_test['세부직종'] + X_test['근무지역_3']
X_test['세부직종+출신대학'] = X_test['세부직종'] + X_test['출신대학']
X_test['세부직종+근무형태'] = X_test['세부직종'] + X_test['근무형태']
X_test['세부직종+마지막근무형태'] = X_test['세부직종'] + X_test['마지막근무형태']

X_train['직무태그+근무경력'] = X_train['직무태그'] + X_train['근무경력']
X_train['직무태그+대학전공'] = X_train['직무태그'] + X_train['대학전공']
X_train['직무태그+어학시험'] = X_train['직무태그'] + X_train['어학시험']
X_train['직무태그+자격증'] = X_train['직무태그'] + X_train['자격증']
#X_train['직무태그+근무개월'] = X_train['직무태그'] + X_train['근무개월']
X_train['직무태그+근무지역_1'] = X_train['직무태그'] + X_train['근무지역_1']
X_train['직무태그+근무지역_2'] = X_train['직무태그'] + X_train['근무지역_2']
X_train['직무태그+근무지역_3'] = X_train['직무태그'] + X_train['근무지역_3']
X_train['직무태그+출신대학'] = X_train['직무태그'] + X_train['출신대학']
X_train['직무태그+근무형태'] = X_train['직무태그'] + X_train['근무형태']
X_train['직무태그+마지막근무형태'] = X_train['직무태그'] + X_train['마지막근무형태']

X_test['직무태그+근무경력'] = X_test['직무태그'] + X_test['근무경력']
X_test['직무태그+대학전공'] = X_test['직무태그'] + X_test['대학전공']
X_test['직무태그+어학시험'] = X_test['직무태그'] + X_test['어학시험']
X_test['직무태그+자격증'] = X_test['직무태그'] + X_test['자격증']
#X_test['직무태그+근무개월'] = X_test['직무태그'] + X_test['근무개월']
X_test['직무태그+근무지역_1'] = X_test['직무태그'] + X_test['근무지역_1']
X_test['직무태그+근무지역_2'] = X_test['직무태그'] + X_test['근무지역_2']
X_test['직무태그+근무지역_3'] = X_test['직무태그'] + X_test['근무지역_3']
X_test['직무태그+출신대학'] = X_test['직무태그'] + X_test['출신대학']
X_test['직무태그+근무형태'] = X_test['직무태그'] + X_test['근무형태']
X_test['직무태그+마지막근무형태'] = X_test['직무태그'] + X_test['마지막근무형태']

X_train['근무경력+대학전공'] = X_train['근무경력'] + X_train['대학전공']
X_train['근무경력+어학시험'] = X_train['근무경력'] + X_train['어학시험']
X_train['근무경력+자격증'] = X_train['근무경력'] + X_train['자격증']
#X_train['근무경력+근무개월'] = X_train['근무경력'] + X_train['근무개월']
X_train['근무경력+근무지역_1'] = X_train['근무경력'] + X_train['근무지역_1']
X_train['근무경력+근무지역_2'] = X_train['근무경력'] + X_train['근무지역_2']
X_train['근무경력+근무지역_3'] = X_train['근무경력'] + X_train['근무지역_3']
X_train['근무경력+출신대학'] = X_train['근무경력'] + X_train['출신대학']
X_train['근무경력+근무형태'] = X_train['근무경력'] + X_train['근무형태']
X_train['근무경력+마지막근무형태'] = X_train['근무경력'] + X_train['마지막근무형태']

X_test['근무경력+대학전공'] = X_test['근무경력'] + X_test['대학전공']
X_test['근무경력+어학시험'] = X_test['근무경력'] + X_test['어학시험']
X_test['근무경력+자격증'] = X_test['근무경력'] + X_test['자격증']
#X_test['근무경력+근무개월'] = X_test['근무경력'] + X_test['근무개월']
X_test['근무경력+근무지역_1'] = X_test['근무경력'] + X_test['근무지역_1']
X_test['근무경력+근무지역_2'] = X_test['근무경력'] + X_test['근무지역_2']
X_test['근무경력+근무지역_3'] = X_test['근무경력'] + X_test['근무지역_3']
X_test['근무경력+출신대학'] = X_test['근무경력'] + X_test['출신대학']
X_test['근무경력+근무형태'] = X_test['근무경력'] + X_test['근무형태']
X_test['근무경력+마지막근무형태'] = X_test['근무경력'] + X_test['마지막근무형태']

X_train['대학전공+어학시험'] = X_train['대학전공'] + X_train['어학시험']
X_train['대학전공+자격증'] = X_train['대학전공'] + X_train['자격증']
#X_train['대학전공+근무개월'] = X_train['대학전공'] + X_train['근무개월']
X_train['대학전공+근무지역_1'] = X_train['대학전공'] + X_train['근무지역_1']
X_train['대학전공+근무지역_2'] = X_train['대학전공'] + X_train['근무지역_2']
X_train['대학전공+근무지역_3'] = X_train['대학전공'] + X_train['근무지역_3']
X_train['대학전공+출신대학'] = X_train['대학전공'] + X_train['출신대학']
X_train['대학전공+근무형태'] = X_train['대학전공'] + X_train['근무형태']
X_train['대학전공+마지막근무형태'] = X_train['대학전공'] + X_train['마지막근무형태']

X_test['대학전공+어학시험'] = X_test['대학전공'] + X_test['어학시험']
X_test['대학전공+자격증'] = X_test['대학전공'] + X_test['자격증']
#X_test['대학전공+근무개월'] = X_test['대학전공'] + X_test['근무개월']
X_test['대학전공+근무지역_1'] = X_test['대학전공'] + X_test['근무지역_1']
X_test['대학전공+근무지역_2'] = X_test['대학전공'] + X_test['근무지역_2']
X_test['대학전공+근무지역_3'] = X_test['대학전공'] + X_test['근무지역_3']
X_test['대학전공+출신대학'] = X_test['대학전공'] + X_test['출신대학']
X_test['대학전공+근무형태'] = X_test['대학전공'] + X_test['근무형태']
X_test['대학전공+마지막근무형태'] = X_test['대학전공'] + X_test['마지막근무형태']

X_train['어학시험+자격증'] = X_train['어학시험'] + X_train['자격증']
#X_train['어학시험+근무개월'] = X_train['어학시험'] + X_train['근무개월']
X_train['어학시험+근무지역_1'] = X_train['어학시험'] + X_train['근무지역_1']
X_train['어학시험+근무지역_2'] = X_train['어학시험'] + X_train['근무지역_2']
X_train['어학시험+근무지역_3'] = X_train['어학시험'] + X_train['근무지역_3']
X_train['어학시험+출신대학'] = X_train['어학시험'] + X_train['출신대학']
X_train['어학시험+근무형태'] = X_train['어학시험'] + X_train['근무형태']
X_train['어학시험+마지막근무형태'] = X_train['어학시험'] + X_train['마지막근무형태']

X_test['어학시험+자격증'] = X_test['어학시험'] + X_test['자격증']
#X_test['어학시험+근무개월'] = X_test['어학시험'] + X_test['근무개월']
X_test['어학시험+근무지역_1'] = X_test['어학시험'] + X_test['근무지역_1']
X_test['어학시험+근무지역_2'] = X_test['어학시험'] + X_test['근무지역_2']
X_test['어학시험+근무지역_3'] = X_test['어학시험'] + X_test['근무지역_3']
X_test['어학시험+출신대학'] = X_test['어학시험'] + X_test['출신대학']
X_test['어학시험+근무형태'] = X_test['어학시험'] + X_test['근무형태']
X_test['어학시험+마지막근무형태'] = X_test['어학시험'] + X_test['마지막근무형태']

#X_train['자격증+근무개월'] = X_train['자격증'] + X_train['근무개월']
X_train['자격증+근무지역_1'] = X_train['자격증'] + X_train['근무지역_1']
X_train['자격증+근무지역_2'] = X_train['자격증'] + X_train['근무지역_2']
X_train['자격증+근무지역_3'] = X_train['자격증'] + X_train['근무지역_3']
X_train['자격증+출신대학'] = X_train['자격증'] + X_train['출신대학']
X_train['자격증+근무형태'] = X_train['자격증'] + X_train['근무형태']
X_train['자격증+마지막근무형태'] = X_train['자격증'] + X_train['마지막근무형태']

#X_test['자격증+근무개월'] = X_test['자격증'] + X_test['근무개월']
X_test['자격증+근무지역_1'] = X_test['자격증'] + X_test['근무지역_1']
X_test['자격증+근무지역_2'] = X_test['자격증'] + X_test['근무지역_2']
X_test['자격증+근무지역_3'] = X_test['자격증'] + X_test['근무지역_3']
X_test['자격증+출신대학'] = X_test['자격증'] + X_test['출신대학']
X_test['자격증+근무형태'] = X_test['자격증'] + X_test['근무형태']
X_test['자격증+마지막근무형태'] = X_test['자격증'] + X_test['마지막근무형태']

X_train['근무지역_1+출신대학'] = X_train['근무지역_1'] + X_train['출신대학']
X_train['근무지역_1+근무형태'] = X_train['근무지역_1'] + X_train['근무형태']
X_train['근무지역_1+마지막근무형태'] = X_train['근무지역_1'] + X_train['마지막근무형태']

X_test['근무지역_1+출신대학'] = X_test['근무지역_1'] + X_test['출신대학']
X_test['근무지역_1+근무형태'] = X_test['근무지역_1'] + X_test['근무형태']
X_test['근무지역_1+마지막근무형태'] = X_test['근무지역_1'] + X_test['마지막근무형태']

X_train['근무지역_2+출신대학'] = X_train['근무지역_2'] + X_train['출신대학']
X_train['근무지역_2+근무형태'] = X_train['근무지역_2'] + X_train['근무형태']
X_train['근무지역_2+마지막근무형태'] = X_train['근무지역_2'] + X_train['마지막근무형태']

X_test['근무지역_2+출신대학'] = X_test['근무지역_2'] + X_test['출신대학']
X_test['근무지역_2+근무형태'] = X_test['근무지역_2'] + X_test['근무형태']
X_test['근무지역_2+마지막근무형태'] = X_test['근무지역_2'] + X_test['마지막근무형태']

X_train['근무지역_3+출신대학'] = X_train['근무지역_3'] + X_train['출신대학']
X_train['근무지역_3+근무형태'] = X_train['근무지역_3'] + X_train['근무형태']
X_train['근무지역_3+마지막근무형태'] = X_train['근무지역_3'] + X_train['마지막근무형태']

X_test['근무지역_3+출신대학'] = X_test['근무지역_3'] + X_test['출신대학']
X_test['근무지역_3+근무형태'] = X_test['근무지역_3'] + X_test['근무형태']
X_test['근무지역_3+마지막근무형태'] = X_test['근무지역_3'] + X_test['마지막근무형태']

X_train['근무형태+출신대학'] = X_train['근무형태'] + X_train['출신대학']

X_test['근무형태+출신대학'] = X_test['근무형태'] + X_test['출신대학']

X_train['마지막근무형태+출신대학'] = X_train['마지막근무형태'] + X_train['출신대학']

X_test['마지막근무형태+출신대학'] = X_test['마지막근무형태'] + X_test['출신대학']

# %%
a = [ '근무지역_1', '근무지역_2', '근무지역_3']
b = ['직종', '세부직종', '직무태그', '근무경력', '근무형태', '출신대학', '대학전공', '어학시험', '자격증']

from itertools import combinations 

b_com = list(combinations(b,3))
b_wecom = list(combinations(b,2))
a_1 = []
a_2 = []
a_3 = []

for i in b_wecom:
    x = ('근무지역_1',)
    a_1.append(i+x)
    
for i in b_wecom:
    x = ('근무지역_2',)
    a_2.append(i+x)

for i in b_wecom:
    x = ('근무지역_3',)
    a_3.append(i+x)
    
c = b_com + a_1 + a_2 + a_3

df = pd.DataFrame()
df_2 = pd.DataFrame()

for i in c:
    df[i] = X_train[i[0]] + X_train[i[1]] + X_train[i[2]]
    df_2[i] = X_test[i[0]] + X_test[i[1]] + X_test[i[2]]

# %%
X_train = pd.concat([X_train,df],axis=1)
X_test = pd.concat([X_test,df_2],axis=1)

# %%
def sinfo(X):    
    for i, j in enumerate(X):
        print(i,j)

# %%
sinfo(X_train)
# Out:
# 0 직종
# 1 세부직종
# 2 직무태그
# 3 근무경력
# 4 근무형태
# 5 근무지역
# 6 출신대학
# 7 대학전공
# 8 어학시험
# 9 자격증
# 10 대학성적
# 11 근무개월
# 12 근무개월log
# 13 대학랭킹
# 14 출신대학수치
# 15 출신대학수치*대학성적
# 16 근무지역_1
# 17 근무지역_2
# 18 근무지역_3
# 19 마지막근무형태
# 20 직무태그_1
# 21 직무태그_2
# 22 직무태그_3
# 23 직무태그_4
# 24 직무태그_5
# 25 직무태그_6
# 26 직무태그_7
# 27 직무태그_8
# 28 직무태그_9
# 29 직무태그_10
# 30 직무태그_11
# 31 직무태그_12
# 32 직무태그_13
# 33 직무태그_14
# 34 직무태그_15
# 35 직무태그_16
# 36 직무태그_17
# 37 직무태그_18
# 38 직무태그_19
# 39 직무태그_20
# 40 직무태그_21
# 41 직무태그_22
# 42 직무태그_23
# 43 직무태그_24
# 44 직무태그_25
# 45 직무태그_26
# 46 직무태그_27
# 47 직무태그개수
# 48 대학성적0.1+근무개월
# 49 출신대학_근무개월_sum
# 50 출신대학_근무개월_mean
# 51 출신대학_근무개월_variance
# 52 출신대학_근무개월_standard_deviation
# 53 직종_근무개월_sum
# 54 직종_근무개월_mean
# 55 직종_근무개월_variance
# 56 직종_근무개월_standard_deviation
# 57 세부직종_근무개월_sum
# 58 세부직종_근무개월_mean
# 59 세부직종_근무개월_variance
# 60 세부직종_근무개월_standard_deviation
# 61 근무지역_1_근무개월_sum
# 62 근무지역_1_근무개월_mean
# 63 근무지역_1_근무개월_variance
# 64 근무지역_1_근무개월_standard_deviation
# 65 근무지역_2_근무개월_sum
# 66 근무지역_2_근무개월_mean
# 67 근무지역_2_근무개월_variance
# 68 근무지역_2_근무개월_standard_deviation
# 69 근무지역_3_근무개월_sum
# 70 근무지역_3_근무개월_mean
# 71 근무지역_3_근무개월_variance
# 72 근무지역_3_근무개월_standard_deviation
# 73 마지막근무형태_근무개월_sum
# 74 마지막근무형태_근무개월_mean
# 75 마지막근무형태_근무개월_variance
# 76 마지막근무형태_근무개월_standard_deviation
# 77 직무태그_1_근무개월_sum
# 78 직무태그_1_근무개월_mean
# 79 직무태그_1_근무개월_variance
# 80 직무태그_1_근무개월_standard_deviation
# 81 대학성적_근무개월_sum
# 82 대학성적_근무개월_mean
# 83 대학성적_근무개월_variance
# 84 대학성적_근무개월_standard_deviation
# 85 대학전공_근무개월_sum
# 86 대학전공_근무개월_mean
# 87 대학전공_근무개월_variance
# 88 대학전공_근무개월_standard_deviation
# 89 어학시험_근무개월_sum
# 90 어학시험_근무개월_mean
# 91 어학시험_근무개월_variance
# 92 어학시험_근무개월_standard_deviation
# 93 직종_세부직종_근무개월_sum
# 94 직종_세부직종_근무개월_mean
# 95 직종_세부직종_근무개월_variance
# 96 직종_세부직종_근무개월_standard_deviation
# 97 직종_근무지역_1_근무개월_sum
# 98 직종_근무지역_1_근무개월_mean
# 99 직종_근무지역_1_근무개월_variance
# 100 직종_근무지역_1_근무개월_standard_deviation
# 101 직종_근무지역_2_근무개월_sum
# 102 직종_근무지역_2_근무개월_mean
# 103 직종_근무지역_2_근무개월_variance
# 104 직종_근무지역_2_근무개월_standard_deviation
# 105 직종_근무지역_3_근무개월_sum
# 106 직종_근무지역_3_근무개월_mean
# 107 직종_근무지역_3_근무개월_variance
# 108 직종_근무지역_3_근무개월_standard_deviation
# 109 직종_마지막근무형태_근무개월_sum
# 110 직종_마지막근무형태_근무개월_mean
# 111 직종_마지막근무형태_근무개월_variance
# 112 직종_마지막근무형태_근무개월_standard_deviation
# 113 직종_직무태그_1_근무개월_sum
# 114 직종_직무태그_1_근무개월_mean
# 115 직종_직무태그_1_근무개월_variance
# 116 직종_직무태그_1_근무개월_standard_deviation
# 117 직종_대학성적_근무개월_sum
# 118 직종_대학성적_근무개월_mean
# 119 직종_대학성적_근무개월_variance
# 120 직종_대학성적_근무개월_standard_deviation
# 121 세부직종_근무지역_1_근무개월_sum
# 122 세부직종_근무지역_1_근무개월_mean
# 123 세부직종_근무지역_1_근무개월_variance
# 124 세부직종_근무지역_1_근무개월_standard_deviation
# 125 세부직종_근무지역_2_근무개월_sum
# 126 세부직종_근무지역_2_근무개월_mean
# 127 세부직종_근무지역_2_근무개월_variance
# 128 세부직종_근무지역_2_근무개월_standard_deviation
# 129 세부직종_근무지역_3_근무개월_sum
# 130 세부직종_근무지역_3_근무개월_mean
# 131 세부직종_근무지역_3_근무개월_variance
# 132 세부직종_근무지역_3_근무개월_standard_deviation
# 133 세부직종_마지막근무형태_근무개월_sum
# 134 세부직종_마지막근무형태_근무개월_mean
# 135 세부직종_마지막근무형태_근무개월_variance
# 136 세부직종_마지막근무형태_근무개월_standard_deviation
# 137 근무지역_1_근무지역_2_근무개월_sum
# 138 근무지역_1_근무지역_2_근무개월_mean
# 139 근무지역_1_근무지역_2_근무개월_variance
# 140 근무지역_1_근무지역_2_근무개월_standard_deviation
# 141 근무지역_1_근무지역_3_근무개월_sum
# 142 근무지역_1_근무지역_3_근무개월_mean
# 143 근무지역_1_근무지역_3_근무개월_variance
# 144 근무지역_1_근무지역_3_근무개월_standard_deviation
# 145 근무지역_2_근무지역_3_근무개월_sum
# 146 근무지역_2_근무지역_3_근무개월_mean
# 147 근무지역_2_근무지역_3_근무개월_variance
# 148 근무지역_2_근무지역_3_근무개월_standard_deviation
# 149 자격증_어학시험_근무개월_sum
# 150 자격증_어학시험_근무개월_mean
# 151 자격증_어학시험_근무개월_variance
# 152 자격증_어학시험_근무개월_standard_deviation
# 153 수치형통합
# 154 출신대학_수치형통합_sum
# 155 출신대학_수치형통합_mean
# 156 출신대학_수치형통합_variance
# 157 출신대학_수치형통합_standard_deviation
# 158 직종_수치형통합_sum
# 159 직종_수치형통합_mean
# 160 직종_수치형통합_variance
# 161 직종_수치형통합_standard_deviation
# 162 세부직종_수치형통합_sum
# 163 세부직종_수치형통합_mean
# 164 세부직종_수치형통합_variance
# 165 세부직종_수치형통합_standard_deviation
# 166 근무지역_1_수치형통합_sum
# 167 근무지역_1_수치형통합_mean
# 168 근무지역_1_수치형통합_variance
# 169 근무지역_1_수치형통합_standard_deviation
# 170 근무지역_2_수치형통합_sum
# 171 근무지역_2_수치형통합_mean
# 172 근무지역_2_수치형통합_variance
# 173 근무지역_2_수치형통합_standard_deviation
# 174 근무지역_3_수치형통합_sum
# 175 근무지역_3_수치형통합_mean
# 176 근무지역_3_수치형통합_variance
# 177 근무지역_3_수치형통합_standard_deviation
# 178 마지막근무형태_수치형통합_sum
# 179 마지막근무형태_수치형통합_mean
# 180 마지막근무형태_수치형통합_variance
# 181 마지막근무형태_수치형통합_standard_deviation
# 182 직무태그_1_수치형통합_sum
# 183 직무태그_1_수치형통합_mean
# 184 직무태그_1_수치형통합_variance
# 185 직무태그_1_수치형통합_standard_deviation
# 186 대학성적_수치형통합_sum
# 187 대학성적_수치형통합_mean
# 188 대학성적_수치형통합_variance
# 189 대학성적_수치형통합_standard_deviation
# 190 대학전공_수치형통합_sum
# 191 대학전공_수치형통합_mean
# 192 대학전공_수치형통합_variance
# 193 대학전공_수치형통합_standard_deviation
# 194 어학시험_수치형통합_sum
# 195 어학시험_수치형통합_mean
# 196 어학시험_수치형통합_variance
# 197 어학시험_수치형통합_standard_deviation
# 198 직종_세부직종_수치형통합_sum
# 199 직종_세부직종_수치형통합_mean
# 200 직종_세부직종_수치형통합_variance
# 201 직종_세부직종_수치형통합_standard_deviation
# 202 직종_근무지역_1_수치형통합_sum
# 203 직종_근무지역_1_수치형통합_mean
# 204 직종_근무지역_1_수치형통합_variance
# 205 직종_근무지역_1_수치형통합_standard_deviation
# 206 직종_근무지역_2_수치형통합_sum
# 207 직종_근무지역_2_수치형통합_mean
# 208 직종_근무지역_2_수치형통합_variance
# 209 직종_근무지역_2_수치형통합_standard_deviation
# 210 직종_근무지역_3_수치형통합_sum
# 211 직종_근무지역_3_수치형통합_mean
# 212 직종_근무지역_3_수치형통합_variance
# 213 직종_근무지역_3_수치형통합_standard_deviation
# 214 직종_마지막근무형태_수치형통합_sum
# 215 직종_마지막근무형태_수치형통합_mean
# 216 직종_마지막근무형태_수치형통합_variance
# 217 직종_마지막근무형태_수치형통합_standard_deviation
# 218 직종_직무태그_1_수치형통합_sum
# 219 직종_직무태그_1_수치형통합_mean
# 220 직종_직무태그_1_수치형통합_variance
# 221 직종_직무태그_1_수치형통합_standard_deviation
# 222 직종_대학성적_수치형통합_sum
# 223 직종_대학성적_수치형통합_mean
# 224 직종_대학성적_수치형통합_variance
# 225 직종_대학성적_수치형통합_standard_deviation
# 226 세부직종_근무지역_1_수치형통합_sum
# 227 세부직종_근무지역_1_수치형통합_mean
# 228 세부직종_근무지역_1_수치형통합_variance
# 229 세부직종_근무지역_1_수치형통합_standard_deviation
# 230 세부직종_근무지역_2_수치형통합_sum
# 231 세부직종_근무지역_2_수치형통합_mean
# 232 세부직종_근무지역_2_수치형통합_variance
# 233 세부직종_근무지역_2_수치형통합_standard_deviation
# 234 세부직종_근무지역_3_수치형통합_sum
# 235 세부직종_근무지역_3_수치형통합_mean
# 236 세부직종_근무지역_3_수치형통합_variance
# 237 세부직종_근무지역_3_수치형통합_standard_deviation
# 238 세부직종_마지막근무형태_수치형통합_sum
# 239 세부직종_마지막근무형태_수치형통합_mean
# 240 세부직종_마지막근무형태_수치형통합_variance
# 241 세부직종_마지막근무형태_수치형통합_standard_deviation
# 242 근무지역_1_근무지역_2_수치형통합_sum
# 243 근무지역_1_근무지역_2_수치형통합_mean
# 244 근무지역_1_근무지역_2_수치형통합_variance
# 245 근무지역_1_근무지역_2_수치형통합_standard_deviation
# 246 근무지역_1_근무지역_3_수치형통합_sum
# 247 근무지역_1_근무지역_3_수치형통합_mean
# 248 근무지역_1_근무지역_3_수치형통합_variance
# 249 근무지역_1_근무지역_3_수치형통합_standard_deviation
# 250 근무지역_2_근무지역_3_수치형통합_sum
# 251 근무지역_2_근무지역_3_수치형통합_mean
# 252 근무지역_2_근무지역_3_수치형통합_variance
# 253 근무지역_2_근무지역_3_수치형통합_standard_deviation
# 254 자격증_어학시험_수치형통합_sum
# 255 자격증_어학시험_수치형통합_mean
# 256 자격증_어학시험_수치형통합_variance
# 257 자격증_어학시험_수치형통합_standard_deviation
# 258 정규직비정규직
# 259 대학+전공
# 260 직종+세부직종
# 261 근무형태+직종
# 262 인서울여부
# 263 자격증또는어학시험유무
# 264 직종+직무태그
# 265 직종+근무경력
# 266 직종+대학전공
# 267 직종+어학시험
# 268 직종+자격증
# 269 직종+근무지역_1
# 270 직종+근무지역_2
# 271 직종+근무지역_3
# 272 직종+출신대학
# 273 직종+마지막근무형태
# 274 세부직종+직무태그
# 275 세부직종+근무경력
# 276 세부직종+대학전공
# 277 세부직종+어학시험
# 278 세부직종+자격증
# 279 세부직종+근무지역_1
# 280 세부직종+근무지역_2
# 281 세부직종+근무지역_3
# 282 세부직종+출신대학
# 283 세부직종+근무형태
# 284 세부직종+마지막근무형태
# 285 직무태그+근무경력
# 286 직무태그+대학전공
# 287 직무태그+어학시험
# 288 직무태그+자격증
# 289 직무태그+근무지역_1
# 290 직무태그+근무지역_2
# 291 직무태그+근무지역_3
# 292 직무태그+출신대학
# 293 직무태그+근무형태
# 294 직무태그+마지막근무형태
# 295 근무경력+대학전공
# 296 근무경력+어학시험
# 297 근무경력+자격증
# 298 근무경력+근무지역_1
# 299 근무경력+근무지역_2
# 300 근무경력+근무지역_3
# 301 근무경력+출신대학
# 302 근무경력+근무형태
# 303 근무경력+마지막근무형태
# 304 대학전공+어학시험
# 305 대학전공+자격증
# 306 대학전공+근무지역_1
# 307 대학전공+근무지역_2
# 308 대학전공+근무지역_3
# 309 대학전공+출신대학
# 310 대학전공+근무형태
# 311 대학전공+마지막근무형태
# 312 어학시험+자격증
# 313 어학시험+근무지역_1
# 314 어학시험+근무지역_2
# 315 어학시험+근무지역_3
# 316 어학시험+출신대학
# 317 어학시험+근무형태
# 318 어학시험+마지막근무형태
# 319 자격증+근무지역_1
# 320 자격증+근무지역_2
# 321 자격증+근무지역_3
# 322 자격증+출신대학
# 323 자격증+근무형태
# 324 자격증+마지막근무형태
# 325 근무지역_1+출신대학
# 326 근무지역_1+근무형태
# 327 근무지역_1+마지막근무형태
# 328 근무지역_2+출신대학
# 329 근무지역_2+근무형태
# 330 근무지역_2+마지막근무형태
# 331 근무지역_3+출신대학
# 332 근무지역_3+근무형태
# 333 근무지역_3+마지막근무형태
# 334 근무형태+출신대학
# 335 마지막근무형태+출신대학
# 336 ('직종', '세부직종', '직무태그')
# 337 ('직종', '세부직종', '근무경력')
# 338 ('직종', '세부직종', '근무형태')
# 339 ('직종', '세부직종', '출신대학')
# 340 ('직종', '세부직종', '대학전공')
# 341 ('직종', '세부직종', '어학시험')
# 342 ('직종', '세부직종', '자격증')
# 343 ('직종', '직무태그', '근무경력')
# 344 ('직종', '직무태그', '근무형태')
# 345 ('직종', '직무태그', '출신대학')
# 346 ('직종', '직무태그', '대학전공')
# 347 ('직종', '직무태그', '어학시험')
# 348 ('직종', '직무태그', '자격증')
# 349 ('직종', '근무경력', '근무형태')
# 350 ('직종', '근무경력', '출신대학')
# 351 ('직종', '근무경력', '대학전공')
# 352 ('직종', '근무경력', '어학시험')
# 353 ('직종', '근무경력', '자격증')
# 354 ('직종', '근무형태', '출신대학')
# 355 ('직종', '근무형태', '대학전공')
# 356 ('직종', '근무형태', '어학시험')
# 357 ('직종', '근무형태', '자격증')
# 358 ('직종', '출신대학', '대학전공')
# 359 ('직종', '출신대학', '어학시험')
# 360 ('직종', '출신대학', '자격증')
# 361 ('직종', '대학전공', '어학시험')
# 362 ('직종', '대학전공', '자격증')
# 363 ('직종', '어학시험', '자격증')
# 364 ('세부직종', '직무태그', '근무경력')
# 365 ('세부직종', '직무태그', '근무형태')
# 366 ('세부직종', '직무태그', '출신대학')
# 367 ('세부직종', '직무태그', '대학전공')
# 368 ('세부직종', '직무태그', '어학시험')
# 369 ('세부직종', '직무태그', '자격증')
# 370 ('세부직종', '근무경력', '근무형태')
# 371 ('세부직종', '근무경력', '출신대학')
# 372 ('세부직종', '근무경력', '대학전공')
# 373 ('세부직종', '근무경력', '어학시험')
# 374 ('세부직종', '근무경력', '자격증')
# 375 ('세부직종', '근무형태', '출신대학')
# 376 ('세부직종', '근무형태', '대학전공')
# 377 ('세부직종', '근무형태', '어학시험')
# 378 ('세부직종', '근무형태', '자격증')
# 379 ('세부직종', '출신대학', '대학전공')
# 380 ('세부직종', '출신대학', '어학시험')
# 381 ('세부직종', '출신대학', '자격증')
# 382 ('세부직종', '대학전공', '어학시험')
# 383 ('세부직종', '대학전공', '자격증')
# 384 ('세부직종', '어학시험', '자격증')
# 385 ('직무태그', '근무경력', '근무형태')
# 386 ('직무태그', '근무경력', '출신대학')
# 387 ('직무태그', '근무경력', '대학전공')
# 388 ('직무태그', '근무경력', '어학시험')
# 389 ('직무태그', '근무경력', '자격증')
# 390 ('직무태그', '근무형태', '출신대학')
# 391 ('직무태그', '근무형태', '대학전공')
# 392 ('직무태그', '근무형태', '어학시험')
# 393 ('직무태그', '근무형태', '자격증')
# 394 ('직무태그', '출신대학', '대학전공')
# 395 ('직무태그', '출신대학', '어학시험')
# 396 ('직무태그', '출신대학', '자격증')
# 397 ('직무태그', '대학전공', '어학시험')
# 398 ('직무태그', '대학전공', '자격증')
# 399 ('직무태그', '어학시험', '자격증')
# 400 ('근무경력', '근무형태', '출신대학')
# 401 ('근무경력', '근무형태', '대학전공')
# 402 ('근무경력', '근무형태', '어학시험')
# 403 ('근무경력', '근무형태', '자격증')
# 404 ('근무경력', '출신대학', '대학전공')
# 405 ('근무경력', '출신대학', '어학시험')
# 406 ('근무경력', '출신대학', '자격증')
# 407 ('근무경력', '대학전공', '어학시험')
# 408 ('근무경력', '대학전공', '자격증')
# 409 ('근무경력', '어학시험', '자격증')
# 410 ('근무형태', '출신대학', '대학전공')
# 411 ('근무형태', '출신대학', '어학시험')
# 412 ('근무형태', '출신대학', '자격증')
# 413 ('근무형태', '대학전공', '어학시험')
# 414 ('근무형태', '대학전공', '자격증')
# 415 ('근무형태', '어학시험', '자격증')
# 416 ('출신대학', '대학전공', '어학시험')
# 417 ('출신대학', '대학전공', '자격증')
# 418 ('출신대학', '어학시험', '자격증')
# 419 ('대학전공', '어학시험', '자격증')
# 420 ('직종', '세부직종', '근무지역_1')
# 421 ('직종', '직무태그', '근무지역_1')
# 422 ('직종', '근무경력', '근무지역_1')
# 423 ('직종', '근무형태', '근무지역_1')
# 424 ('직종', '출신대학', '근무지역_1')
# 425 ('직종', '대학전공', '근무지역_1')
# 426 ('직종', '어학시험', '근무지역_1')
# 427 ('직종', '자격증', '근무지역_1')
# 428 ('세부직종', '직무태그', '근무지역_1')
# 429 ('세부직종', '근무경력', '근무지역_1')
# 430 ('세부직종', '근무형태', '근무지역_1')
# 431 ('세부직종', '출신대학', '근무지역_1')
# 432 ('세부직종', '대학전공', '근무지역_1')
# 433 ('세부직종', '어학시험', '근무지역_1')
# 434 ('세부직종', '자격증', '근무지역_1')
# 435 ('직무태그', '근무경력', '근무지역_1')
# 436 ('직무태그', '근무형태', '근무지역_1')
# 437 ('직무태그', '출신대학', '근무지역_1')
# 438 ('직무태그', '대학전공', '근무지역_1')
# 439 ('직무태그', '어학시험', '근무지역_1')
# 440 ('직무태그', '자격증', '근무지역_1')
# 441 ('근무경력', '근무형태', '근무지역_1')
# 442 ('근무경력', '출신대학', '근무지역_1')
# 443 ('근무경력', '대학전공', '근무지역_1')
# 444 ('근무경력', '어학시험', '근무지역_1')
# 445 ('근무경력', '자격증', '근무지역_1')
# 446 ('근무형태', '출신대학', '근무지역_1')
# 447 ('근무형태', '대학전공', '근무지역_1')
# 448 ('근무형태', '어학시험', '근무지역_1')
# 449 ('근무형태', '자격증', '근무지역_1')
# 450 ('출신대학', '대학전공', '근무지역_1')
# 451 ('출신대학', '어학시험', '근무지역_1')
# 452 ('출신대학', '자격증', '근무지역_1')
# 453 ('대학전공', '어학시험', '근무지역_1')
# 454 ('대학전공', '자격증', '근무지역_1')
# 455 ('어학시험', '자격증', '근무지역_1')
# 456 ('직종', '세부직종', '근무지역_2')
# 457 ('직종', '직무태그', '근무지역_2')
# 458 ('직종', '근무경력', '근무지역_2')
# 459 ('직종', '근무형태', '근무지역_2')
# 460 ('직종', '출신대학', '근무지역_2')
# 461 ('직종', '대학전공', '근무지역_2')
# 462 ('직종', '어학시험', '근무지역_2')
# 463 ('직종', '자격증', '근무지역_2')
# 464 ('세부직종', '직무태그', '근무지역_2')
# 465 ('세부직종', '근무경력', '근무지역_2')
# 466 ('세부직종', '근무형태', '근무지역_2')
# 467 ('세부직종', '출신대학', '근무지역_2')
# 468 ('세부직종', '대학전공', '근무지역_2')
# 469 ('세부직종', '어학시험', '근무지역_2')
# 470 ('세부직종', '자격증', '근무지역_2')
# 471 ('직무태그', '근무경력', '근무지역_2')
# 472 ('직무태그', '근무형태', '근무지역_2')
# 473 ('직무태그', '출신대학', '근무지역_2')
# 474 ('직무태그', '대학전공', '근무지역_2')
# 475 ('직무태그', '어학시험', '근무지역_2')
# 476 ('직무태그', '자격증', '근무지역_2')
# 477 ('근무경력', '근무형태', '근무지역_2')
# 478 ('근무경력', '출신대학', '근무지역_2')
# 479 ('근무경력', '대학전공', '근무지역_2')
# 480 ('근무경력', '어학시험', '근무지역_2')
# 481 ('근무경력', '자격증', '근무지역_2')
# 482 ('근무형태', '출신대학', '근무지역_2')
# 483 ('근무형태', '대학전공', '근무지역_2')
# 484 ('근무형태', '어학시험', '근무지역_2')
# 485 ('근무형태', '자격증', '근무지역_2')
# 486 ('출신대학', '대학전공', '근무지역_2')
# 487 ('출신대학', '어학시험', '근무지역_2')
# 488 ('출신대학', '자격증', '근무지역_2')
# 489 ('대학전공', '어학시험', '근무지역_2')
# 490 ('대학전공', '자격증', '근무지역_2')
# 491 ('어학시험', '자격증', '근무지역_2')
# 492 ('직종', '세부직종', '근무지역_3')
# 493 ('직종', '직무태그', '근무지역_3')
# 494 ('직종', '근무경력', '근무지역_3')
# 495 ('직종', '근무형태', '근무지역_3')
# 496 ('직종', '출신대학', '근무지역_3')
# 497 ('직종', '대학전공', '근무지역_3')
# 498 ('직종', '어학시험', '근무지역_3')
# 499 ('직종', '자격증', '근무지역_3')
# 500 ('세부직종', '직무태그', '근무지역_3')
# 501 ('세부직종', '근무경력', '근무지역_3')
# 502 ('세부직종', '근무형태', '근무지역_3')
# 503 ('세부직종', '출신대학', '근무지역_3')
# 504 ('세부직종', '대학전공', '근무지역_3')
# 505 ('세부직종', '어학시험', '근무지역_3')
# 506 ('세부직종', '자격증', '근무지역_3')
# 507 ('직무태그', '근무경력', '근무지역_3')
# 508 ('직무태그', '근무형태', '근무지역_3')
# 509 ('직무태그', '출신대학', '근무지역_3')
# 510 ('직무태그', '대학전공', '근무지역_3')
# 511 ('직무태그', '어학시험', '근무지역_3')
# 512 ('직무태그', '자격증', '근무지역_3')
# 513 ('근무경력', '근무형태', '근무지역_3')
# 514 ('근무경력', '출신대학', '근무지역_3')
# 515 ('근무경력', '대학전공', '근무지역_3')
# 516 ('근무경력', '어학시험', '근무지역_3')
# 517 ('근무경력', '자격증', '근무지역_3')
# 518 ('근무형태', '출신대학', '근무지역_3')
# 519 ('근무형태', '대학전공', '근무지역_3')
# 520 ('근무형태', '어학시험', '근무지역_3')
# 521 ('근무형태', '자격증', '근무지역_3')
# 522 ('출신대학', '대학전공', '근무지역_3')
# 523 ('출신대학', '어학시험', '근무지역_3')
# 524 ('출신대학', '자격증', '근무지역_3')
# 525 ('대학전공', '어학시험', '근무지역_3')
# 526 ('대학전공', '자격증', '근무지역_3')
# 527 ('어학시험', '자격증', '근무지역_3')

# %%
cat = ['직종', '세부직종', '직무태그', '근무지역','근무경력', '출신대학', '대학전공','어학시험', '자격증']

# Label Encoding 528,536
from sklearn.preprocessing import LabelEncoder

for i in cat:
    X_train[i+'label'] = LabelEncoder().fit_transform(X_train[i])
    
for i in cat:
    X_test[i+'label'] = LabelEncoder().fit_transform(X_test[i])

# %%
for i in X_train.iloc[:,528:-1].columns:
    print(type(X_train[i][0]))
# Out:
# <class 'numpy.int32'>
# <class 'numpy.int32'>
# <class 'numpy.int32'>
# <class 'numpy.int32'>
# <class 'numpy.int32'>
# <class 'numpy.int32'>
# <class 'numpy.int32'>
# <class 'numpy.int32'>

# %%
len(X_train)
# Out:
# 16570

# %%
X_train.iloc[:,528].value_counts()
# Out:
# 2     7332
# 0     2396
# 7     2352
# 8     1266
# 1     1193
# 9      882
# 5      605
# 10     188
# 3      150
# 6      119
# 4       87
# Name: 직종label, dtype: int64

# %%
for i in X_train.iloc[:,528:-1].columns:
    X_train[i] = X_train[i] +1

# %%
#537, 774
a = X_train.iloc[:,528:-1].columns
a_com2 = list(combinations(a,2))
a_com3 = list(combinations(a,3))
a_com4 = list(combinations(a,4))
a_com5 = list(combinations(a,5))
a_com6 = list(combinations(a,6))

for i in a_com2:
    X_train[i[0]+i[1]] = X_train[i[0]] * X_train[i[1]]
    X_test[i[0]+i[1]] = X_test[i[0]] * X_test[i[1]]

for i in a_com3:
    X_train[i[0]+i[1]+i[2]] = X_train[i[0]] * X_train[i[1]] * X_train[i[2]]
    X_test[i[0]+i[1]+i[2]] = X_test[i[0]] * X_test[i[1]] * X_test[i[2]]

for i in a_com4:
    X_train[i[0]+i[1]+i[2]+i[3]] = X_train[i[0]] * X_train[i[1]] * X_train[i[2]]*X_train[i[3]]
    X_test[i[0]+i[1]+i[2]+i[3]] = X_test[i[0]] * X_test[i[1]] * X_test[i[2]]*X_test[i[3]]

for i in a_com5:
    X_train[i[0]+i[1]+i[2]+i[3]+i[4]] = X_train[i[0]] * X_train[i[1]] * X_train[i[2]]*X_train[i[3]]*X_train[i[4]]
    X_test[i[0]+i[1]+i[2]+i[3]+i[4]] = X_test[i[0]] * X_test[i[1]] * X_test[i[2]]*X_test[i[3]]*X_test[i[4]]

for i in a_com6:
    X_train[i[0]+i[1]+i[2]+i[3]+i[4]+i[5]] = X_train[i[0]] * X_train[i[1]] * X_train[i[2]]*X_train[i[3]]*X_train[i[4]]*X_train[i[5]]
    X_test[i[0]+i[1]+i[2]+i[3]+i[4]+i[5]] = X_test[i[0]] * X_test[i[1]] * X_test[i[2]]*X_test[i[3]]*X_test[i[4]]*X_test[i[5]]

# %%
a_com2[0][1]
# Out:
# '세부직종label'

# %%
sinfo(X_train)
# Out:
# 0 직종
# 1 세부직종
# 2 직무태그
# 3 근무경력
# 4 근무형태
# 5 근무지역
# 6 출신대학
# 7 대학전공
# 8 어학시험
# 9 자격증
# 10 대학성적
# 11 근무개월
# 12 근무개월log
# 13 대학랭킹
# 14 출신대학수치
# 15 출신대학수치*대학성적
# 16 근무지역_1
# 17 근무지역_2
# 18 근무지역_3
# 19 마지막근무형태
# 20 직무태그_1
# 21 직무태그_2
# 22 직무태그_3
# 23 직무태그_4
# 24 직무태그_5
# 25 직무태그_6
# 26 직무태그_7
# 27 직무태그_8
# 28 직무태그_9
# 29 직무태그_10
# 30 직무태그_11
# 31 직무태그_12
# 32 직무태그_13
# 33 직무태그_14
# 34 직무태그_15
# 35 직무태그_16
# 36 직무태그_17
# 37 직무태그_18
# 38 직무태그_19
# 39 직무태그_20
# 40 직무태그_21
# 41 직무태그_22
# 42 직무태그_23
# 43 직무태그_24
# 44 직무태그_25
# 45 직무태그_26
# 46 직무태그_27
# 47 직무태그개수
# 48 대학성적0.1+근무개월
# 49 출신대학_근무개월_sum
# 50 출신대학_근무개월_mean
# 51 출신대학_근무개월_variance
# 52 출신대학_근무개월_standard_deviation
# 53 직종_근무개월_sum
# 54 직종_근무개월_mean
# 55 직종_근무개월_variance
# 56 직종_근무개월_standard_deviation
# 57 세부직종_근무개월_sum
# 58 세부직종_근무개월_mean
# 59 세부직종_근무개월_variance
# 60 세부직종_근무개월_standard_deviation
# 61 근무지역_1_근무개월_sum
# 62 근무지역_1_근무개월_mean
# 63 근무지역_1_근무개월_variance
# 64 근무지역_1_근무개월_standard_deviation
# 65 근무지역_2_근무개월_sum
# 66 근무지역_2_근무개월_mean
# 67 근무지역_2_근무개월_variance
# 68 근무지역_2_근무개월_standard_deviation
# 69 근무지역_3_근무개월_sum
# 70 근무지역_3_근무개월_mean
# 71 근무지역_3_근무개월_variance
# 72 근무지역_3_근무개월_standard_deviation
# 73 마지막근무형태_근무개월_sum
# 74 마지막근무형태_근무개월_mean
# 75 마지막근무형태_근무개월_variance
# 76 마지막근무형태_근무개월_standard_deviation
# 77 직무태그_1_근무개월_sum
# 78 직무태그_1_근무개월_mean
# 79 직무태그_1_근무개월_variance
# 80 직무태그_1_근무개월_standard_deviation
# 81 대학성적_근무개월_sum
# 82 대학성적_근무개월_mean
# 83 대학성적_근무개월_variance
# 84 대학성적_근무개월_standard_deviation
# 85 대학전공_근무개월_sum
# 86 대학전공_근무개월_mean
# 87 대학전공_근무개월_variance
# 88 대학전공_근무개월_standard_deviation
# 89 어학시험_근무개월_sum
# 90 어학시험_근무개월_mean
# 91 어학시험_근무개월_variance
# 92 어학시험_근무개월_standard_deviation
# 93 직종_세부직종_근무개월_sum
# 94 직종_세부직종_근무개월_mean
# 95 직종_세부직종_근무개월_variance
# 96 직종_세부직종_근무개월_standard_deviation
# 97 직종_근무지역_1_근무개월_sum
# 98 직종_근무지역_1_근무개월_mean
# 99 직종_근무지역_1_근무개월_variance
# 100 직종_근무지역_1_근무개월_standard_deviation
# 101 직종_근무지역_2_근무개월_sum
# 102 직종_근무지역_2_근무개월_mean
# 103 직종_근무지역_2_근무개월_variance
# 104 직종_근무지역_2_근무개월_standard_deviation
# 105 직종_근무지역_3_근무개월_sum
# 106 직종_근무지역_3_근무개월_mean
# 107 직종_근무지역_3_근무개월_variance
# 108 직종_근무지역_3_근무개월_standard_deviation
# 109 직종_마지막근무형태_근무개월_sum
# 110 직종_마지막근무형태_근무개월_mean
# 111 직종_마지막근무형태_근무개월_variance
# 112 직종_마지막근무형태_근무개월_standard_deviation
# 113 직종_직무태그_1_근무개월_sum
# 114 직종_직무태그_1_근무개월_mean
# 115 직종_직무태그_1_근무개월_variance
# 116 직종_직무태그_1_근무개월_standard_deviation
# 117 직종_대학성적_근무개월_sum
# 118 직종_대학성적_근무개월_mean
# 119 직종_대학성적_근무개월_variance
# 120 직종_대학성적_근무개월_standard_deviation
# 121 세부직종_근무지역_1_근무개월_sum
# 122 세부직종_근무지역_1_근무개월_mean
# 123 세부직종_근무지역_1_근무개월_variance
# 124 세부직종_근무지역_1_근무개월_standard_deviation
# 125 세부직종_근무지역_2_근무개월_sum
# 126 세부직종_근무지역_2_근무개월_mean
# 127 세부직종_근무지역_2_근무개월_variance
# 128 세부직종_근무지역_2_근무개월_standard_deviation
# 129 세부직종_근무지역_3_근무개월_sum
# 130 세부직종_근무지역_3_근무개월_mean
# 131 세부직종_근무지역_3_근무개월_variance
# 132 세부직종_근무지역_3_근무개월_standard_deviation
# 133 세부직종_마지막근무형태_근무개월_sum
# 134 세부직종_마지막근무형태_근무개월_mean
# 135 세부직종_마지막근무형태_근무개월_variance
# 136 세부직종_마지막근무형태_근무개월_standard_deviation
# 137 근무지역_1_근무지역_2_근무개월_sum
# 138 근무지역_1_근무지역_2_근무개월_mean
# 139 근무지역_1_근무지역_2_근무개월_variance
# 140 근무지역_1_근무지역_2_근무개월_standard_deviation
# 141 근무지역_1_근무지역_3_근무개월_sum
# 142 근무지역_1_근무지역_3_근무개월_mean
# 143 근무지역_1_근무지역_3_근무개월_variance
# 144 근무지역_1_근무지역_3_근무개월_standard_deviation
# 145 근무지역_2_근무지역_3_근무개월_sum
# 146 근무지역_2_근무지역_3_근무개월_mean
# 147 근무지역_2_근무지역_3_근무개월_variance
# 148 근무지역_2_근무지역_3_근무개월_standard_deviation
# 149 자격증_어학시험_근무개월_sum
# 150 자격증_어학시험_근무개월_mean
# 151 자격증_어학시험_근무개월_variance
# 152 자격증_어학시험_근무개월_standard_deviation
# 153 수치형통합
# 154 출신대학_수치형통합_sum
# 155 출신대학_수치형통합_mean
# 156 출신대학_수치형통합_variance
# 157 출신대학_수치형통합_standard_deviation
# 158 직종_수치형통합_sum
# 159 직종_수치형통합_mean
# 160 직종_수치형통합_variance
# 161 직종_수치형통합_standard_deviation
# 162 세부직종_수치형통합_sum
# 163 세부직종_수치형통합_mean
# 164 세부직종_수치형통합_variance
# 165 세부직종_수치형통합_standard_deviation
# 166 근무지역_1_수치형통합_sum
# 167 근무지역_1_수치형통합_mean
# 168 근무지역_1_수치형통합_variance
# 169 근무지역_1_수치형통합_standard_deviation
# 170 근무지역_2_수치형통합_sum
# 171 근무지역_2_수치형통합_mean
# 172 근무지역_2_수치형통합_variance
# 173 근무지역_2_수치형통합_standard_deviation
# 174 근무지역_3_수치형통합_sum
# 175 근무지역_3_수치형통합_mean
# 176 근무지역_3_수치형통합_variance
# 177 근무지역_3_수치형통합_standard_deviation
# 178 마지막근무형태_수치형통합_sum
# 179 마지막근무형태_수치형통합_mean
# 180 마지막근무형태_수치형통합_variance
# 181 마지막근무형태_수치형통합_standard_deviation
# 182 직무태그_1_수치형통합_sum
# 183 직무태그_1_수치형통합_mean
# 184 직무태그_1_수치형통합_variance
# 185 직무태그_1_수치형통합_standard_deviation
# 186 대학성적_수치형통합_sum
# 187 대학성적_수치형통합_mean
# 188 대학성적_수치형통합_variance
# 189 대학성적_수치형통합_standard_deviation
# 190 대학전공_수치형통합_sum
# 191 대학전공_수치형통합_mean
# 192 대학전공_수치형통합_variance
# 193 대학전공_수치형통합_standard_deviation
# 194 어학시험_수치형통합_sum
# 195 어학시험_수치형통합_mean
# 196 어학시험_수치형통합_variance
# 197 어학시험_수치형통합_standard_deviation
# 198 직종_세부직종_수치형통합_sum
# 199 직종_세부직종_수치형통합_mean
# 200 직종_세부직종_수치형통합_variance
# 201 직종_세부직종_수치형통합_standard_deviation
# 202 직종_근무지역_1_수치형통합_sum
# 203 직종_근무지역_1_수치형통합_mean
# 204 직종_근무지역_1_수치형통합_variance
# 205 직종_근무지역_1_수치형통합_standard_deviation
# 206 직종_근무지역_2_수치형통합_sum
# 207 직종_근무지역_2_수치형통합_mean
# 208 직종_근무지역_2_수치형통합_variance
# 209 직종_근무지역_2_수치형통합_standard_deviation
# 210 직종_근무지역_3_수치형통합_sum
# 211 직종_근무지역_3_수치형통합_mean
# 212 직종_근무지역_3_수치형통합_variance
# 213 직종_근무지역_3_수치형통합_standard_deviation
# 214 직종_마지막근무형태_수치형통합_sum
# 215 직종_마지막근무형태_수치형통합_mean
# 216 직종_마지막근무형태_수치형통합_variance
# 217 직종_마지막근무형태_수치형통합_standard_deviation
# 218 직종_직무태그_1_수치형통합_sum
# 219 직종_직무태그_1_수치형통합_mean
# 220 직종_직무태그_1_수치형통합_variance
# 221 직종_직무태그_1_수치형통합_standard_deviation
# 222 직종_대학성적_수치형통합_sum
# 223 직종_대학성적_수치형통합_mean
# 224 직종_대학성적_수치형통합_variance
# 225 직종_대학성적_수치형통합_standard_deviation
# 226 세부직종_근무지역_1_수치형통합_sum
# 227 세부직종_근무지역_1_수치형통합_mean
# 228 세부직종_근무지역_1_수치형통합_variance
# 229 세부직종_근무지역_1_수치형통합_standard_deviation
# 230 세부직종_근무지역_2_수치형통합_sum
# 231 세부직종_근무지역_2_수치형통합_mean
# 232 세부직종_근무지역_2_수치형통합_variance
# 233 세부직종_근무지역_2_수치형통합_standard_deviation
# 234 세부직종_근무지역_3_수치형통합_sum
# 235 세부직종_근무지역_3_수치형통합_mean
# 236 세부직종_근무지역_3_수치형통합_variance
# 237 세부직종_근무지역_3_수치형통합_standard_deviation
# 238 세부직종_마지막근무형태_수치형통합_sum
# 239 세부직종_마지막근무형태_수치형통합_mean
# 240 세부직종_마지막근무형태_수치형통합_variance
# 241 세부직종_마지막근무형태_수치형통합_standard_deviation
# 242 근무지역_1_근무지역_2_수치형통합_sum
# 243 근무지역_1_근무지역_2_수치형통합_mean
# 244 근무지역_1_근무지역_2_수치형통합_variance
# 245 근무지역_1_근무지역_2_수치형통합_standard_deviation
# 246 근무지역_1_근무지역_3_수치형통합_sum
# 247 근무지역_1_근무지역_3_수치형통합_mean
# 248 근무지역_1_근무지역_3_수치형통합_variance
# 249 근무지역_1_근무지역_3_수치형통합_standard_deviation
# 250 근무지역_2_근무지역_3_수치형통합_sum
# 251 근무지역_2_근무지역_3_수치형통합_mean
# 252 근무지역_2_근무지역_3_수치형통합_variance
# 253 근무지역_2_근무지역_3_수치형통합_standard_deviation
# 254 자격증_어학시험_수치형통합_sum
# 255 자격증_어학시험_수치형통합_mean
# 256 자격증_어학시험_수치형통합_variance
# 257 자격증_어학시험_수치형통합_standard_deviation
# 258 정규직비정규직
# 259 대학+전공
# 260 직종+세부직종
# 261 근무형태+직종
# 262 인서울여부
# 263 자격증또는어학시험유무
# 264 직종+직무태그
# 265 직종+근무경력
# 266 직종+대학전공
# 267 직종+어학시험
# 268 직종+자격증
# 269 직종+근무지역_1
# 270 직종+근무지역_2
# 271 직종+근무지역_3
# 272 직종+출신대학
# 273 직종+마지막근무형태
# 274 세부직종+직무태그
# 275 세부직종+근무경력
# 276 세부직종+대학전공
# 277 세부직종+어학시험
# 278 세부직종+자격증
# 279 세부직종+근무지역_1
# 280 세부직종+근무지역_2
# 281 세부직종+근무지역_3
# 282 세부직종+출신대학
# 283 세부직종+근무형태
# 284 세부직종+마지막근무형태
# 285 직무태그+근무경력
# 286 직무태그+대학전공
# 287 직무태그+어학시험
# 288 직무태그+자격증
# 289 직무태그+근무지역_1
# 290 직무태그+근무지역_2
# 291 직무태그+근무지역_3
# 292 직무태그+출신대학
# 293 직무태그+근무형태
# 294 직무태그+마지막근무형태
# 295 근무경력+대학전공
# 296 근무경력+어학시험
# 297 근무경력+자격증
# 298 근무경력+근무지역_1
# 299 근무경력+근무지역_2
# 300 근무경력+근무지역_3
# 301 근무경력+출신대학
# 302 근무경력+근무형태
# 303 근무경력+마지막근무형태
# 304 대학전공+어학시험
# 305 대학전공+자격증
# 306 대학전공+근무지역_1
# 307 대학전공+근무지역_2
# 308 대학전공+근무지역_3
# 309 대학전공+출신대학
# 310 대학전공+근무형태
# 311 대학전공+마지막근무형태
# 312 어학시험+자격증
# 313 어학시험+근무지역_1
# 314 어학시험+근무지역_2
# 315 어학시험+근무지역_3
# 316 어학시험+출신대학
# 317 어학시험+근무형태
# 318 어학시험+마지막근무형태
# 319 자격증+근무지역_1
# 320 자격증+근무지역_2
# 321 자격증+근무지역_3
# 322 자격증+출신대학
# 323 자격증+근무형태
# 324 자격증+마지막근무형태
# 325 근무지역_1+출신대학
# 326 근무지역_1+근무형태
# 327 근무지역_1+마지막근무형태
# 328 근무지역_2+출신대학
# 329 근무지역_2+근무형태
# 330 근무지역_2+마지막근무형태
# 331 근무지역_3+출신대학
# 332 근무지역_3+근무형태
# 333 근무지역_3+마지막근무형태
# 334 근무형태+출신대학
# 335 마지막근무형태+출신대학
# 336 ('직종', '세부직종', '직무태그')
# 337 ('직종', '세부직종', '근무경력')
# 338 ('직종', '세부직종', '근무형태')
# 339 ('직종', '세부직종', '출신대학')
# 340 ('직종', '세부직종', '대학전공')
# 341 ('직종', '세부직종', '어학시험')
# 342 ('직종', '세부직종', '자격증')
# 343 ('직종', '직무태그', '근무경력')
# 344 ('직종', '직무태그', '근무형태')
# 345 ('직종', '직무태그', '출신대학')
# 346 ('직종', '직무태그', '대학전공')
# 347 ('직종', '직무태그', '어학시험')
# 348 ('직종', '직무태그', '자격증')
# 349 ('직종', '근무경력', '근무형태')
# 350 ('직종', '근무경력', '출신대학')
# 351 ('직종', '근무경력', '대학전공')
# 352 ('직종', '근무경력', '어학시험')
# 353 ('직종', '근무경력', '자격증')
# 354 ('직종', '근무형태', '출신대학')
# 355 ('직종', '근무형태', '대학전공')
# 356 ('직종', '근무형태', '어학시험')
# 357 ('직종', '근무형태', '자격증')
# 358 ('직종', '출신대학', '대학전공')
# 359 ('직종', '출신대학', '어학시험')
# 360 ('직종', '출신대학', '자격증')
# 361 ('직종', '대학전공', '어학시험')
# 362 ('직종', '대학전공', '자격증')
# 363 ('직종', '어학시험', '자격증')
# 364 ('세부직종', '직무태그', '근무경력')
# 365 ('세부직종', '직무태그', '근무형태')
# 366 ('세부직종', '직무태그', '출신대학')
# 367 ('세부직종', '직무태그', '대학전공')
# 368 ('세부직종', '직무태그', '어학시험')
# 369 ('세부직종', '직무태그', '자격증')
# 370 ('세부직종', '근무경력', '근무형태')
# 371 ('세부직종', '근무경력', '출신대학')
# 372 ('세부직종', '근무경력', '대학전공')
# 373 ('세부직종', '근무경력', '어학시험')
# 374 ('세부직종', '근무경력', '자격증')
# 375 ('세부직종', '근무형태', '출신대학')
# 376 ('세부직종', '근무형태', '대학전공')
# 377 ('세부직종', '근무형태', '어학시험')
# 378 ('세부직종', '근무형태', '자격증')
# 379 ('세부직종', '출신대학', '대학전공')
# 380 ('세부직종', '출신대학', '어학시험')
# 381 ('세부직종', '출신대학', '자격증')
# 382 ('세부직종', '대학전공', '어학시험')
# 383 ('세부직종', '대학전공', '자격증')
# 384 ('세부직종', '어학시험', '자격증')
# 385 ('직무태그', '근무경력', '근무형태')
# 386 ('직무태그', '근무경력', '출신대학')
# 387 ('직무태그', '근무경력', '대학전공')
# 388 ('직무태그', '근무경력', '어학시험')
# 389 ('직무태그', '근무경력', '자격증')
# 390 ('직무태그', '근무형태', '출신대학')
# 391 ('직무태그', '근무형태', '대학전공')
# 392 ('직무태그', '근무형태', '어학시험')
# 393 ('직무태그', '근무형태', '자격증')
# 394 ('직무태그', '출신대학', '대학전공')
# 395 ('직무태그', '출신대학', '어학시험')
# 396 ('직무태그', '출신대학', '자격증')
# 397 ('직무태그', '대학전공', '어학시험')
# 398 ('직무태그', '대학전공', '자격증')
# 399 ('직무태그', '어학시험', '자격증')
# 400 ('근무경력', '근무형태', '출신대학')
# 401 ('근무경력', '근무형태', '대학전공')
# 402 ('근무경력', '근무형태', '어학시험')
# 403 ('근무경력', '근무형태', '자격증')
# 404 ('근무경력', '출신대학', '대학전공')
# 405 ('근무경력', '출신대학', '어학시험')
# 406 ('근무경력', '출신대학', '자격증')
# 407 ('근무경력', '대학전공', '어학시험')
# 408 ('근무경력', '대학전공', '자격증')
# 409 ('근무경력', '어학시험', '자격증')
# 410 ('근무형태', '출신대학', '대학전공')
# 411 ('근무형태', '출신대학', '어학시험')
# 412 ('근무형태', '출신대학', '자격증')
# 413 ('근무형태', '대학전공', '어학시험')
# 414 ('근무형태', '대학전공', '자격증')
# 415 ('근무형태', '어학시험', '자격증')
# 416 ('출신대학', '대학전공', '어학시험')
# 417 ('출신대학', '대학전공', '자격증')
# 418 ('출신대학', '어학시험', '자격증')
# 419 ('대학전공', '어학시험', '자격증')
# 420 ('직종', '세부직종', '근무지역_1')
# 421 ('직종', '직무태그', '근무지역_1')
# 422 ('직종', '근무경력', '근무지역_1')
# 423 ('직종', '근무형태', '근무지역_1')
# 424 ('직종', '출신대학', '근무지역_1')
# 425 ('직종', '대학전공', '근무지역_1')
# 426 ('직종', '어학시험', '근무지역_1')
# 427 ('직종', '자격증', '근무지역_1')
# 428 ('세부직종', '직무태그', '근무지역_1')
# 429 ('세부직종', '근무경력', '근무지역_1')
# 430 ('세부직종', '근무형태', '근무지역_1')
# 431 ('세부직종', '출신대학', '근무지역_1')
# 432 ('세부직종', '대학전공', '근무지역_1')
# 433 ('세부직종', '어학시험', '근무지역_1')
# 434 ('세부직종', '자격증', '근무지역_1')
# 435 ('직무태그', '근무경력', '근무지역_1')
# 436 ('직무태그', '근무형태', '근무지역_1')
# 437 ('직무태그', '출신대학', '근무지역_1')
# 438 ('직무태그', '대학전공', '근무지역_1')
# 439 ('직무태그', '어학시험', '근무지역_1')
# 440 ('직무태그', '자격증', '근무지역_1')
# 441 ('근무경력', '근무형태', '근무지역_1')
# 442 ('근무경력', '출신대학', '근무지역_1')
# 443 ('근무경력', '대학전공', '근무지역_1')
# 444 ('근무경력', '어학시험', '근무지역_1')
# 445 ('근무경력', '자격증', '근무지역_1')
# 446 ('근무형태', '출신대학', '근무지역_1')
# 447 ('근무형태', '대학전공', '근무지역_1')
# 448 ('근무형태', '어학시험', '근무지역_1')
# 449 ('근무형태', '자격증', '근무지역_1')
# 450 ('출신대학', '대학전공', '근무지역_1')
# 451 ('출신대학', '어학시험', '근무지역_1')
# 452 ('출신대학', '자격증', '근무지역_1')
# 453 ('대학전공', '어학시험', '근무지역_1')
# 454 ('대학전공', '자격증', '근무지역_1')
# 455 ('어학시험', '자격증', '근무지역_1')
# 456 ('직종', '세부직종', '근무지역_2')
# 457 ('직종', '직무태그', '근무지역_2')
# 458 ('직종', '근무경력', '근무지역_2')
# 459 ('직종', '근무형태', '근무지역_2')
# 460 ('직종', '출신대학', '근무지역_2')
# 461 ('직종', '대학전공', '근무지역_2')
# 462 ('직종', '어학시험', '근무지역_2')
# 463 ('직종', '자격증', '근무지역_2')
# 464 ('세부직종', '직무태그', '근무지역_2')
# 465 ('세부직종', '근무경력', '근무지역_2')
# 466 ('세부직종', '근무형태', '근무지역_2')
# 467 ('세부직종', '출신대학', '근무지역_2')
# 468 ('세부직종', '대학전공', '근무지역_2')
# 469 ('세부직종', '어학시험', '근무지역_2')
# 470 ('세부직종', '자격증', '근무지역_2')
# 471 ('직무태그', '근무경력', '근무지역_2')
# 472 ('직무태그', '근무형태', '근무지역_2')
# 473 ('직무태그', '출신대학', '근무지역_2')
# 474 ('직무태그', '대학전공', '근무지역_2')
# 475 ('직무태그', '어학시험', '근무지역_2')
# 476 ('직무태그', '자격증', '근무지역_2')
# 477 ('근무경력', '근무형태', '근무지역_2')
# 478 ('근무경력', '출신대학', '근무지역_2')
# 479 ('근무경력', '대학전공', '근무지역_2')
# 480 ('근무경력', '어학시험', '근무지역_2')
# 481 ('근무경력', '자격증', '근무지역_2')
# 482 ('근무형태', '출신대학', '근무지역_2')
# 483 ('근무형태', '대학전공', '근무지역_2')
# 484 ('근무형태', '어학시험', '근무지역_2')
# 485 ('근무형태', '자격증', '근무지역_2')
# 486 ('출신대학', '대학전공', '근무지역_2')
# 487 ('출신대학', '어학시험', '근무지역_2')
# 488 ('출신대학', '자격증', '근무지역_2')
# 489 ('대학전공', '어학시험', '근무지역_2')
# 490 ('대학전공', '자격증', '근무지역_2')
# 491 ('어학시험', '자격증', '근무지역_2')
# 492 ('직종', '세부직종', '근무지역_3')
# 493 ('직종', '직무태그', '근무지역_3')
# 494 ('직종', '근무경력', '근무지역_3')
# 495 ('직종', '근무형태', '근무지역_3')
# 496 ('직종', '출신대학', '근무지역_3')
# 497 ('직종', '대학전공', '근무지역_3')
# 498 ('직종', '어학시험', '근무지역_3')
# 499 ('직종', '자격증', '근무지역_3')
# 500 ('세부직종', '직무태그', '근무지역_3')
# 501 ('세부직종', '근무경력', '근무지역_3')
# 502 ('세부직종', '근무형태', '근무지역_3')
# 503 ('세부직종', '출신대학', '근무지역_3')
# 504 ('세부직종', '대학전공', '근무지역_3')
# 505 ('세부직종', '어학시험', '근무지역_3')
# 506 ('세부직종', '자격증', '근무지역_3')
# 507 ('직무태그', '근무경력', '근무지역_3')
# 508 ('직무태그', '근무형태', '근무지역_3')
# 509 ('직무태그', '출신대학', '근무지역_3')
# 510 ('직무태그', '대학전공', '근무지역_3')
# 511 ('직무태그', '어학시험', '근무지역_3')
# 512 ('직무태그', '자격증', '근무지역_3')
# 513 ('근무경력', '근무형태', '근무지역_3')
# 514 ('근무경력', '출신대학', '근무지역_3')
# 515 ('근무경력', '대학전공', '근무지역_3')
# 516 ('근무경력', '어학시험', '근무지역_3')
# 517 ('근무경력', '자격증', '근무지역_3')
# 518 ('근무형태', '출신대학', '근무지역_3')
# 519 ('근무형태', '대학전공', '근무지역_3')
# 520 ('근무형태', '어학시험', '근무지역_3')
# 521 ('근무형태', '자격증', '근무지역_3')
# 522 ('출신대학', '대학전공', '근무지역_3')
# 523 ('출신대학', '어학시험', '근무지역_3')
# 524 ('출신대학', '자격증', '근무지역_3')
# 525 ('대학전공', '어학시험', '근무지역_3')
# 526 ('대학전공', '자격증', '근무지역_3')
# 527 ('어학시험', '자격증', '근무지역_3')
# 528 직종label
# 529 세부직종label
# 530 직무태그label
# 531 근무지역label
# 532 근무경력label
# 533 출신대학label
# 534 대학전공label
# 535 어학시험label
# 536 자격증label
# 537 직종label세부직종label
# 538 직종label직무태그label
# 539 직종label근무지역label
# 540 직종label근무경력label
# 541 직종label출신대학label
# 542 직종label대학전공label
# 543 직종label어학시험label
# 544 세부직종label직무태그label
# 545 세부직종label근무지역label
# 546 세부직종label근무경력label
# 547 세부직종label출신대학label
# 548 세부직종label대학전공label
# 549 세부직종label어학시험label
# 550 직무태그label근무지역label
# 551 직무태그label근무경력label
# 552 직무태그label출신대학label
# 553 직무태그label대학전공label
# 554 직무태그label어학시험label
# 555 근무지역label근무경력label
# 556 근무지역label출신대학label
# 557 근무지역label대학전공label
# 558 근무지역label어학시험label
# 559 근무경력label출신대학label
# 560 근무경력label대학전공label
# 561 근무경력label어학시험label
# 562 출신대학label대학전공label
# 563 출신대학label어학시험label
# 564 대학전공label어학시험label
# 565 직종label세부직종label직무태그label
# 566 직종label세부직종label근무지역label
# 567 직종label세부직종label근무경력label
# 568 직종label세부직종label출신대학label
# 569 직종label세부직종label대학전공label
# 570 직종label세부직종label어학시험label
# 571 직종label직무태그label근무지역label
# 572 직종label직무태그label근무경력label
# 573 직종label직무태그label출신대학label
# 574 직종label직무태그label대학전공label
# 575 직종label직무태그label어학시험label
# 576 직종label근무지역label근무경력label
# 577 직종label근무지역label출신대학label
# 578 직종label근무지역label대학전공label
# 579 직종label근무지역label어학시험label
# 580 직종label근무경력label출신대학label
# 581 직종label근무경력label대학전공label
# 582 직종label근무경력label어학시험label
# 583 직종label출신대학label대학전공label
# 584 직종label출신대학label어학시험label
# 585 직종label대학전공label어학시험label
# 586 세부직종label직무태그label근무지역label
# 587 세부직종label직무태그label근무경력label
# 588 세부직종label직무태그label출신대학label
# 589 세부직종label직무태그label대학전공label
# 590 세부직종label직무태그label어학시험label
# 591 세부직종label근무지역label근무경력label
# 592 세부직종label근무지역label출신대학label
# 593 세부직종label근무지역label대학전공label
# 594 세부직종label근무지역label어학시험label
# 595 세부직종label근무경력label출신대학label
# 596 세부직종label근무경력label대학전공label
# 597 세부직종label근무경력label어학시험label
# 598 세부직종label출신대학label대학전공label
# 599 세부직종label출신대학label어학시험label
# 600 세부직종label대학전공label어학시험label
# 601 직무태그label근무지역label근무경력label
# 602 직무태그label근무지역label출신대학label
# 603 직무태그label근무지역label대학전공label
# 604 직무태그label근무지역label어학시험label
# 605 직무태그label근무경력label출신대학label
# 606 직무태그label근무경력label대학전공label
# 607 직무태그label근무경력label어학시험label
# 608 직무태그label출신대학label대학전공label
# 609 직무태그label출신대학label어학시험label
# 610 직무태그label대학전공label어학시험label
# 611 근무지역label근무경력label출신대학label
# 612 근무지역label근무경력label대학전공label
# 613 근무지역label근무경력label어학시험label
# 614 근무지역label출신대학label대학전공label
# 615 근무지역label출신대학label어학시험label
# 616 근무지역label대학전공label어학시험label
# 617 근무경력label출신대학label대학전공label
# 618 근무경력label출신대학label어학시험label
# 619 근무경력label대학전공label어학시험label
# 620 출신대학label대학전공label어학시험label
# 621 직종label세부직종label직무태그label근무지역label
# 622 직종label세부직종label직무태그label근무경력label
# 623 직종label세부직종label직무태그label출신대학label
# 624 직종label세부직종label직무태그label대학전공label
# 625 직종label세부직종label직무태그label어학시험label
# 626 직종label세부직종label근무지역label근무경력label
# 627 직종label세부직종label근무지역label출신대학label
# 628 직종label세부직종label근무지역label대학전공label
# 629 직종label세부직종label근무지역label어학시험label
# 630 직종label세부직종label근무경력label출신대학label
# 631 직종label세부직종label근무경력label대학전공label
# 632 직종label세부직종label근무경력label어학시험label
# 633 직종label세부직종label출신대학label대학전공label
# 634 직종label세부직종label출신대학label어학시험label
# 635 직종label세부직종label대학전공label어학시험label
# 636 직종label직무태그label근무지역label근무경력label
# 637 직종label직무태그label근무지역label출신대학label
# 638 직종label직무태그label근무지역label대학전공label
# 639 직종label직무태그label근무지역label어학시험label
# 640 직종label직무태그label근무경력label출신대학label
# 641 직종label직무태그label근무경력label대학전공label
# 642 직종label직무태그label근무경력label어학시험label
# 643 직종label직무태그label출신대학label대학전공label
# 644 직종label직무태그label출신대학label어학시험label
# 645 직종label직무태그label대학전공label어학시험label
# 646 직종label근무지역label근무경력label출신대학label
# 647 직종label근무지역label근무경력label대학전공label
# 648 직종label근무지역label근무경력label어학시험label
# 649 직종label근무지역label출신대학label대학전공label
# 650 직종label근무지역label출신대학label어학시험label
# 651 직종label근무지역label대학전공label어학시험label
# 652 직종label근무경력label출신대학label대학전공label
# 653 직종label근무경력label출신대학label어학시험label
# 654 직종label근무경력label대학전공label어학시험label
# 655 직종label출신대학label대학전공label어학시험label
# 656 세부직종label직무태그label근무지역label근무경력label
# 657 세부직종label직무태그label근무지역label출신대학label
# 658 세부직종label직무태그label근무지역label대학전공label
# 659 세부직종label직무태그label근무지역label어학시험label
# 660 세부직종label직무태그label근무경력label출신대학label
# 661 세부직종label직무태그label근무경력label대학전공label
# 662 세부직종label직무태그label근무경력label어학시험label
# 663 세부직종label직무태그label출신대학label대학전공label
# 664 세부직종label직무태그label출신대학label어학시험label
# 665 세부직종label직무태그label대학전공label어학시험label
# 666 세부직종label근무지역label근무경력label출신대학label
# 667 세부직종label근무지역label근무경력label대학전공label
# 668 세부직종label근무지역label근무경력label어학시험label
# 669 세부직종label근무지역label출신대학label대학전공label
# 670 세부직종label근무지역label출신대학label어학시험label
# 671 세부직종label근무지역label대학전공label어학시험label
# 672 세부직종label근무경력label출신대학label대학전공label
# 673 세부직종label근무경력label출신대학label어학시험label
# 674 세부직종label근무경력label대학전공label어학시험label
# 675 세부직종label출신대학label대학전공label어학시험label
# 676 직무태그label근무지역label근무경력label출신대학label
# 677 직무태그label근무지역label근무경력label대학전공label
# 678 직무태그label근무지역label근무경력label어학시험label
# 679 직무태그label근무지역label출신대학label대학전공label
# 680 직무태그label근무지역label출신대학label어학시험label
# 681 직무태그label근무지역label대학전공label어학시험label
# 682 직무태그label근무경력label출신대학label대학전공label
# 683 직무태그label근무경력label출신대학label어학시험label
# 684 직무태그label근무경력label대학전공label어학시험label
# 685 직무태그label출신대학label대학전공label어학시험label
# 686 근무지역label근무경력label출신대학label대학전공label
# 687 근무지역label근무경력label출신대학label어학시험label
# 688 근무지역label근무경력label대학전공label어학시험label
# 689 근무지역label출신대학label대학전공label어학시험label
# 690 근무경력label출신대학label대학전공label어학시험label
# 691 직종label세부직종label직무태그label근무지역label근무경력label
# 692 직종label세부직종label직무태그label근무지역label출신대학label
# 693 직종label세부직종label직무태그label근무지역label대학전공label
# 694 직종label세부직종label직무태그label근무지역label어학시험label
# 695 직종label세부직종label직무태그label근무경력label출신대학label
# 696 직종label세부직종label직무태그label근무경력label대학전공label
# 697 직종label세부직종label직무태그label근무경력label어학시험label
# 698 직종label세부직종label직무태그label출신대학label대학전공label
# 699 직종label세부직종label직무태그label출신대학label어학시험label
# 700 직종label세부직종label직무태그label대학전공label어학시험label
# 701 직종label세부직종label근무지역label근무경력label출신대학label
# 702 직종label세부직종label근무지역label근무경력label대학전공label
# 703 직종label세부직종label근무지역label근무경력label어학시험label
# 704 직종label세부직종label근무지역label출신대학label대학전공label
# 705 직종label세부직종label근무지역label출신대학label어학시험label
# 706 직종label세부직종label근무지역label대학전공label어학시험label
# 707 직종label세부직종label근무경력label출신대학label대학전공label
# 708 직종label세부직종label근무경력label출신대학label어학시험label
# 709 직종label세부직종label근무경력label대학전공label어학시험label
# 710 직종label세부직종label출신대학label대학전공label어학시험label
# 711 직종label직무태그label근무지역label근무경력label출신대학label
# 712 직종label직무태그label근무지역label근무경력label대학전공label
# 713 직종label직무태그label근무지역label근무경력label어학시험label
# 714 직종label직무태그label근무지역label출신대학label대학전공label
# 715 직종label직무태그label근무지역label출신대학label어학시험label
# 716 직종label직무태그label근무지역label대학전공label어학시험label
# 717 직종label직무태그label근무경력label출신대학label대학전공label
# 718 직종label직무태그label근무경력label출신대학label어학시험label
# 719 직종label직무태그label근무경력label대학전공label어학시험label
# 720 직종label직무태그label출신대학label대학전공label어학시험label
# 721 직종label근무지역label근무경력label출신대학label대학전공label
# 722 직종label근무지역label근무경력label출신대학label어학시험label
# 723 직종label근무지역label근무경력label대학전공label어학시험label
# 724 직종label근무지역label출신대학label대학전공label어학시험label
# 725 직종label근무경력label출신대학label대학전공label어학시험label
# 726 세부직종label직무태그label근무지역label근무경력label출신대학label
# 727 세부직종label직무태그label근무지역label근무경력label대학전공label
# 728 세부직종label직무태그label근무지역label근무경력label어학시험label
# 729 세부직종label직무태그label근무지역label출신대학label대학전공label
# 730 세부직종label직무태그label근무지역label출신대학label어학시험label
# 731 세부직종label직무태그label근무지역label대학전공label어학시험label
# 732 세부직종label직무태그label근무경력label출신대학label대학전공label
# 733 세부직종label직무태그label근무경력label출신대학label어학시험label
# 734 세부직종label직무태그label근무경력label대학전공label어학시험label
# 735 세부직종label직무태그label출신대학label대학전공label어학시험label
# 736 세부직종label근무지역label근무경력label출신대학label대학전공label
# 737 세부직종label근무지역label근무경력label출신대학label어학시험label
# 738 세부직종label근무지역label근무경력label대학전공label어학시험label
# 739 세부직종label근무지역label출신대학label대학전공label어학시험label
# 740 세부직종label근무경력label출신대학label대학전공label어학시험label
# 741 직무태그label근무지역label근무경력label출신대학label대학전공label
# 742 직무태그label근무지역label근무경력label출신대학label어학시험label
# 743 직무태그label근무지역label근무경력label대학전공label어학시험label
# 744 직무태그label근무지역label출신대학label대학전공label어학시험label
# 745 직무태그label근무경력label출신대학label대학전공label어학시험label
# 746 근무지역label근무경력label출신대학label대학전공label어학시험label
# 747 직종label세부직종label직무태그label근무지역label근무경력label출신대학label
# 748 직종label세부직종label직무태그label근무지역label근무경력label대학전공label
# 749 직종label세부직종label직무태그label근무지역label근무경력label어학시험label
# 750 직종label세부직종label직무태그label근무지역label출신대학label대학전공label
# 751 직종label세부직종label직무태그label근무지역label출신대학label어학시험label
# 752 직종label세부직종label직무태그label근무지역label대학전공label어학시험label
# 753 직종label세부직종label직무태그label근무경력label출신대학label대학전공label
# 754 직종label세부직종label직무태그label근무경력label출신대학label어학시험label
# 755 직종label세부직종label직무태그label근무경력label대학전공label어학시험label
# 756 직종label세부직종label직무태그label출신대학label대학전공label어학시험label
# 757 직종label세부직종label근무지역label근무경력label출신대학label대학전공label
# 758 직종label세부직종label근무지역label근무경력label출신대학label어학시험label
# 759 직종label세부직종label근무지역label근무경력label대학전공label어학시험label
# 760 직종label세부직종label근무지역label출신대학label대학전공label어학시험label
# 761 직종label세부직종label근무경력label출신대학label대학전공label어학시험label
# 762 직종label직무태그label근무지역label근무경력label출신대학label대학전공label
# 763 직종label직무태그label근무지역label근무경력label출신대학label어학시험label
# 764 직종label직무태그label근무지역label근무경력label대학전공label어학시험label
# 765 직종label직무태그label근무지역label출신대학label대학전공label어학시험label
# 766 직종label직무태그label근무경력label출신대학label대학전공label어학시험label
# 767 직종label근무지역label근무경력label출신대학label대학전공label어학시험label
# 768 세부직종label직무태그label근무지역label근무경력label출신대학label대학전공label
# 769 세부직종label직무태그label근무지역label근무경력label출신대학label어학시험label
# 770 세부직종label직무태그label근무지역label근무경력label대학전공label어학시험label
# 771 세부직종label직무태그label근무지역label출신대학label대학전공label어학시험label
# 772 세부직종label직무태그label근무경력label출신대학label대학전공label어학시험label
# 773 세부직종label근무지역label근무경력label출신대학label대학전공label어학시험label
# 774 직무태그label근무지역label근무경력label출신대학label대학전공label어학시험label

# %%
#776,1012
for i in X_train.iloc[:,537:775].columns:
    X_train[i,'_log'] = np.log1p(1+X_train[i])
    X_test[i,'_log'] = np.log1p(1+X_test[i])

# %%
sinfo(X_train)
# Out:
# 0 직종
# 1 세부직종
# 2 직무태그
# 3 근무경력
# 4 근무형태
# 5 근무지역
# 6 출신대학
# 7 대학전공
# 8 어학시험
# 9 자격증
# 10 대학성적
# 11 근무개월
# 12 근무개월log
# 13 대학랭킹
# 14 출신대학수치
# 15 출신대학수치*대학성적
# 16 근무지역_1
# 17 근무지역_2
# 18 근무지역_3
# 19 마지막근무형태
# 20 직무태그_1
# 21 직무태그_2
# 22 직무태그_3
# 23 직무태그_4
# 24 직무태그_5
# 25 직무태그_6
# 26 직무태그_7
# 27 직무태그_8
# 28 직무태그_9
# 29 직무태그_10
# 30 직무태그_11
# 31 직무태그_12
# 32 직무태그_13
# 33 직무태그_14
# 34 직무태그_15
# 35 직무태그_16
# 36 직무태그_17
# 37 직무태그_18
# 38 직무태그_19
# 39 직무태그_20
# 40 직무태그_21
# 41 직무태그_22
# 42 직무태그_23
# 43 직무태그_24
# 44 직무태그_25
# 45 직무태그_26
# 46 직무태그_27
# 47 직무태그개수
# 48 대학성적0.1+근무개월
# 49 출신대학_근무개월_sum
# 50 출신대학_근무개월_mean
# 51 출신대학_근무개월_variance
# 52 출신대학_근무개월_standard_deviation
# 53 직종_근무개월_sum
# 54 직종_근무개월_mean
# 55 직종_근무개월_variance
# 56 직종_근무개월_standard_deviation
# 57 세부직종_근무개월_sum
# 58 세부직종_근무개월_mean
# 59 세부직종_근무개월_variance
# 60 세부직종_근무개월_standard_deviation
# 61 근무지역_1_근무개월_sum
# 62 근무지역_1_근무개월_mean
# 63 근무지역_1_근무개월_variance
# 64 근무지역_1_근무개월_standard_deviation
# 65 근무지역_2_근무개월_sum
# 66 근무지역_2_근무개월_mean
# 67 근무지역_2_근무개월_variance
# 68 근무지역_2_근무개월_standard_deviation
# 69 근무지역_3_근무개월_sum
# 70 근무지역_3_근무개월_mean
# 71 근무지역_3_근무개월_variance
# 72 근무지역_3_근무개월_standard_deviation
# 73 마지막근무형태_근무개월_sum
# 74 마지막근무형태_근무개월_mean
# 75 마지막근무형태_근무개월_variance
# 76 마지막근무형태_근무개월_standard_deviation
# 77 직무태그_1_근무개월_sum
# 78 직무태그_1_근무개월_mean
# 79 직무태그_1_근무개월_variance
# 80 직무태그_1_근무개월_standard_deviation
# 81 대학성적_근무개월_sum
# 82 대학성적_근무개월_mean
# 83 대학성적_근무개월_variance
# 84 대학성적_근무개월_standard_deviation
# 85 대학전공_근무개월_sum
# 86 대학전공_근무개월_mean
# 87 대학전공_근무개월_variance
# 88 대학전공_근무개월_standard_deviation
# 89 어학시험_근무개월_sum
# 90 어학시험_근무개월_mean
# 91 어학시험_근무개월_variance
# 92 어학시험_근무개월_standard_deviation
# 93 직종_세부직종_근무개월_sum
# 94 직종_세부직종_근무개월_mean
# 95 직종_세부직종_근무개월_variance
# 96 직종_세부직종_근무개월_standard_deviation
# 97 직종_근무지역_1_근무개월_sum
# 98 직종_근무지역_1_근무개월_mean
# 99 직종_근무지역_1_근무개월_variance
# 100 직종_근무지역_1_근무개월_standard_deviation
# 101 직종_근무지역_2_근무개월_sum
# 102 직종_근무지역_2_근무개월_mean
# 103 직종_근무지역_2_근무개월_variance
# 104 직종_근무지역_2_근무개월_standard_deviation
# 105 직종_근무지역_3_근무개월_sum
# 106 직종_근무지역_3_근무개월_mean
# 107 직종_근무지역_3_근무개월_variance
# 108 직종_근무지역_3_근무개월_standard_deviation
# 109 직종_마지막근무형태_근무개월_sum
# 110 직종_마지막근무형태_근무개월_mean
# 111 직종_마지막근무형태_근무개월_variance
# 112 직종_마지막근무형태_근무개월_standard_deviation
# 113 직종_직무태그_1_근무개월_sum
# 114 직종_직무태그_1_근무개월_mean
# 115 직종_직무태그_1_근무개월_variance
# 116 직종_직무태그_1_근무개월_standard_deviation
# 117 직종_대학성적_근무개월_sum
# 118 직종_대학성적_근무개월_mean
# 119 직종_대학성적_근무개월_variance
# 120 직종_대학성적_근무개월_standard_deviation
# 121 세부직종_근무지역_1_근무개월_sum
# 122 세부직종_근무지역_1_근무개월_mean
# 123 세부직종_근무지역_1_근무개월_variance
# 124 세부직종_근무지역_1_근무개월_standard_deviation
# 125 세부직종_근무지역_2_근무개월_sum
# 126 세부직종_근무지역_2_근무개월_mean
# 127 세부직종_근무지역_2_근무개월_variance
# 128 세부직종_근무지역_2_근무개월_standard_deviation
# 129 세부직종_근무지역_3_근무개월_sum
# 130 세부직종_근무지역_3_근무개월_mean
# 131 세부직종_근무지역_3_근무개월_variance
# 132 세부직종_근무지역_3_근무개월_standard_deviation
# 133 세부직종_마지막근무형태_근무개월_sum
# 134 세부직종_마지막근무형태_근무개월_mean
# 135 세부직종_마지막근무형태_근무개월_variance
# 136 세부직종_마지막근무형태_근무개월_standard_deviation
# 137 근무지역_1_근무지역_2_근무개월_sum
# 138 근무지역_1_근무지역_2_근무개월_mean
# 139 근무지역_1_근무지역_2_근무개월_variance
# 140 근무지역_1_근무지역_2_근무개월_standard_deviation
# 141 근무지역_1_근무지역_3_근무개월_sum
# 142 근무지역_1_근무지역_3_근무개월_mean
# 143 근무지역_1_근무지역_3_근무개월_variance
# 144 근무지역_1_근무지역_3_근무개월_standard_deviation
# 145 근무지역_2_근무지역_3_근무개월_sum
# 146 근무지역_2_근무지역_3_근무개월_mean
# 147 근무지역_2_근무지역_3_근무개월_variance
# 148 근무지역_2_근무지역_3_근무개월_standard_deviation
# 149 자격증_어학시험_근무개월_sum
# 150 자격증_어학시험_근무개월_mean
# 151 자격증_어학시험_근무개월_variance
# 152 자격증_어학시험_근무개월_standard_deviation
# 153 수치형통합
# 154 출신대학_수치형통합_sum
# 155 출신대학_수치형통합_mean
# 156 출신대학_수치형통합_variance
# 157 출신대학_수치형통합_standard_deviation
# 158 직종_수치형통합_sum
# 159 직종_수치형통합_mean
# 160 직종_수치형통합_variance
# 161 직종_수치형통합_standard_deviation
# 162 세부직종_수치형통합_sum
# 163 세부직종_수치형통합_mean
# 164 세부직종_수치형통합_variance
# 165 세부직종_수치형통합_standard_deviation
# 166 근무지역_1_수치형통합_sum
# 167 근무지역_1_수치형통합_mean
# 168 근무지역_1_수치형통합_variance
# 169 근무지역_1_수치형통합_standard_deviation
# 170 근무지역_2_수치형통합_sum
# 171 근무지역_2_수치형통합_mean
# 172 근무지역_2_수치형통합_variance
# 173 근무지역_2_수치형통합_standard_deviation
# 174 근무지역_3_수치형통합_sum
# 175 근무지역_3_수치형통합_mean
# 176 근무지역_3_수치형통합_variance
# 177 근무지역_3_수치형통합_standard_deviation
# 178 마지막근무형태_수치형통합_sum
# 179 마지막근무형태_수치형통합_mean
# 180 마지막근무형태_수치형통합_variance
# 181 마지막근무형태_수치형통합_standard_deviation
# 182 직무태그_1_수치형통합_sum
# 183 직무태그_1_수치형통합_mean
# 184 직무태그_1_수치형통합_variance
# 185 직무태그_1_수치형통합_standard_deviation
# 186 대학성적_수치형통합_sum
# 187 대학성적_수치형통합_mean
# 188 대학성적_수치형통합_variance
# 189 대학성적_수치형통합_standard_deviation
# 190 대학전공_수치형통합_sum
# 191 대학전공_수치형통합_mean
# 192 대학전공_수치형통합_variance
# 193 대학전공_수치형통합_standard_deviation
# 194 어학시험_수치형통합_sum
# 195 어학시험_수치형통합_mean
# 196 어학시험_수치형통합_variance
# 197 어학시험_수치형통합_standard_deviation
# 198 직종_세부직종_수치형통합_sum
# 199 직종_세부직종_수치형통합_mean
# 200 직종_세부직종_수치형통합_variance
# 201 직종_세부직종_수치형통합_standard_deviation
# 202 직종_근무지역_1_수치형통합_sum
# 203 직종_근무지역_1_수치형통합_mean
# 204 직종_근무지역_1_수치형통합_variance
# 205 직종_근무지역_1_수치형통합_standard_deviation
# 206 직종_근무지역_2_수치형통합_sum
# 207 직종_근무지역_2_수치형통합_mean
# 208 직종_근무지역_2_수치형통합_variance
# 209 직종_근무지역_2_수치형통합_standard_deviation
# 210 직종_근무지역_3_수치형통합_sum
# 211 직종_근무지역_3_수치형통합_mean
# 212 직종_근무지역_3_수치형통합_variance
# 213 직종_근무지역_3_수치형통합_standard_deviation
# 214 직종_마지막근무형태_수치형통합_sum
# 215 직종_마지막근무형태_수치형통합_mean
# 216 직종_마지막근무형태_수치형통합_variance
# 217 직종_마지막근무형태_수치형통합_standard_deviation
# 218 직종_직무태그_1_수치형통합_sum
# 219 직종_직무태그_1_수치형통합_mean
# 220 직종_직무태그_1_수치형통합_variance
# 221 직종_직무태그_1_수치형통합_standard_deviation
# 222 직종_대학성적_수치형통합_sum
# 223 직종_대학성적_수치형통합_mean
# 224 직종_대학성적_수치형통합_variance
# 225 직종_대학성적_수치형통합_standard_deviation
# 226 세부직종_근무지역_1_수치형통합_sum
# 227 세부직종_근무지역_1_수치형통합_mean
# 228 세부직종_근무지역_1_수치형통합_variance
# 229 세부직종_근무지역_1_수치형통합_standard_deviation
# 230 세부직종_근무지역_2_수치형통합_sum
# 231 세부직종_근무지역_2_수치형통합_mean
# 232 세부직종_근무지역_2_수치형통합_variance
# 233 세부직종_근무지역_2_수치형통합_standard_deviation
# 234 세부직종_근무지역_3_수치형통합_sum
# 235 세부직종_근무지역_3_수치형통합_mean
# 236 세부직종_근무지역_3_수치형통합_variance
# 237 세부직종_근무지역_3_수치형통합_standard_deviation
# 238 세부직종_마지막근무형태_수치형통합_sum
# 239 세부직종_마지막근무형태_수치형통합_mean
# 240 세부직종_마지막근무형태_수치형통합_variance
# 241 세부직종_마지막근무형태_수치형통합_standard_deviation
# 242 근무지역_1_근무지역_2_수치형통합_sum
# 243 근무지역_1_근무지역_2_수치형통합_mean
# 244 근무지역_1_근무지역_2_수치형통합_variance
# 245 근무지역_1_근무지역_2_수치형통합_standard_deviation
# 246 근무지역_1_근무지역_3_수치형통합_sum
# 247 근무지역_1_근무지역_3_수치형통합_mean
# 248 근무지역_1_근무지역_3_수치형통합_variance
# 249 근무지역_1_근무지역_3_수치형통합_standard_deviation
# 250 근무지역_2_근무지역_3_수치형통합_sum
# 251 근무지역_2_근무지역_3_수치형통합_mean
# 252 근무지역_2_근무지역_3_수치형통합_variance
# 253 근무지역_2_근무지역_3_수치형통합_standard_deviation
# 254 자격증_어학시험_수치형통합_sum
# 255 자격증_어학시험_수치형통합_mean
# 256 자격증_어학시험_수치형통합_variance
# 257 자격증_어학시험_수치형통합_standard_deviation
# 258 정규직비정규직
# 259 대학+전공
# 260 직종+세부직종
# 261 근무형태+직종
# 262 인서울여부
# 263 자격증또는어학시험유무
# 264 직종+직무태그
# 265 직종+근무경력
# 266 직종+대학전공
# 267 직종+어학시험
# 268 직종+자격증
# 269 직종+근무지역_1
# 270 직종+근무지역_2
# 271 직종+근무지역_3
# 272 직종+출신대학
# 273 직종+마지막근무형태
# 274 세부직종+직무태그
# 275 세부직종+근무경력
# 276 세부직종+대학전공
# 277 세부직종+어학시험
# 278 세부직종+자격증
# 279 세부직종+근무지역_1
# 280 세부직종+근무지역_2
# 281 세부직종+근무지역_3
# 282 세부직종+출신대학
# 283 세부직종+근무형태
# 284 세부직종+마지막근무형태
# 285 직무태그+근무경력
# 286 직무태그+대학전공
# 287 직무태그+어학시험
# 288 직무태그+자격증
# 289 직무태그+근무지역_1
# 290 직무태그+근무지역_2
# 291 직무태그+근무지역_3
# 292 직무태그+출신대학
# 293 직무태그+근무형태
# 294 직무태그+마지막근무형태
# 295 근무경력+대학전공
# 296 근무경력+어학시험
# 297 근무경력+자격증
# 298 근무경력+근무지역_1
# 299 근무경력+근무지역_2
# 300 근무경력+근무지역_3
# 301 근무경력+출신대학
# 302 근무경력+근무형태
# 303 근무경력+마지막근무형태
# 304 대학전공+어학시험
# 305 대학전공+자격증
# 306 대학전공+근무지역_1
# 307 대학전공+근무지역_2
# 308 대학전공+근무지역_3
# 309 대학전공+출신대학
# 310 대학전공+근무형태
# 311 대학전공+마지막근무형태
# 312 어학시험+자격증
# 313 어학시험+근무지역_1
# 314 어학시험+근무지역_2
# 315 어학시험+근무지역_3
# 316 어학시험+출신대학
# 317 어학시험+근무형태
# 318 어학시험+마지막근무형태
# 319 자격증+근무지역_1
# 320 자격증+근무지역_2
# 321 자격증+근무지역_3
# 322 자격증+출신대학
# 323 자격증+근무형태
# 324 자격증+마지막근무형태
# 325 근무지역_1+출신대학
# 326 근무지역_1+근무형태
# 327 근무지역_1+마지막근무형태
# 328 근무지역_2+출신대학
# 329 근무지역_2+근무형태
# 330 근무지역_2+마지막근무형태
# 331 근무지역_3+출신대학
# 332 근무지역_3+근무형태
# 333 근무지역_3+마지막근무형태
# 334 근무형태+출신대학
# 335 마지막근무형태+출신대학
# 336 ('직종', '세부직종', '직무태그')
# 337 ('직종', '세부직종', '근무경력')
# 338 ('직종', '세부직종', '근무형태')
# 339 ('직종', '세부직종', '출신대학')
# 340 ('직종', '세부직종', '대학전공')
# 341 ('직종', '세부직종', '어학시험')
# 342 ('직종', '세부직종', '자격증')
# 343 ('직종', '직무태그', '근무경력')
# 344 ('직종', '직무태그', '근무형태')
# 345 ('직종', '직무태그', '출신대학')
# 346 ('직종', '직무태그', '대학전공')
# 347 ('직종', '직무태그', '어학시험')
# 348 ('직종', '직무태그', '자격증')
# 349 ('직종', '근무경력', '근무형태')
# 350 ('직종', '근무경력', '출신대학')
# 351 ('직종', '근무경력', '대학전공')
# 352 ('직종', '근무경력', '어학시험')
# 353 ('직종', '근무경력', '자격증')
# 354 ('직종', '근무형태', '출신대학')
# 355 ('직종', '근무형태', '대학전공')
# 356 ('직종', '근무형태', '어학시험')
# 357 ('직종', '근무형태', '자격증')
# 358 ('직종', '출신대학', '대학전공')
# 359 ('직종', '출신대학', '어학시험')
# 360 ('직종', '출신대학', '자격증')
# 361 ('직종', '대학전공', '어학시험')
# 362 ('직종', '대학전공', '자격증')
# 363 ('직종', '어학시험', '자격증')
# 364 ('세부직종', '직무태그', '근무경력')
# 365 ('세부직종', '직무태그', '근무형태')
# 366 ('세부직종', '직무태그', '출신대학')
# 367 ('세부직종', '직무태그', '대학전공')
# 368 ('세부직종', '직무태그', '어학시험')
# 369 ('세부직종', '직무태그', '자격증')
# 370 ('세부직종', '근무경력', '근무형태')
# 371 ('세부직종', '근무경력', '출신대학')
# 372 ('세부직종', '근무경력', '대학전공')
# 373 ('세부직종', '근무경력', '어학시험')
# 374 ('세부직종', '근무경력', '자격증')
# 375 ('세부직종', '근무형태', '출신대학')
# 376 ('세부직종', '근무형태', '대학전공')
# 377 ('세부직종', '근무형태', '어학시험')
# 378 ('세부직종', '근무형태', '자격증')
# 379 ('세부직종', '출신대학', '대학전공')
# 380 ('세부직종', '출신대학', '어학시험')
# 381 ('세부직종', '출신대학', '자격증')
# 382 ('세부직종', '대학전공', '어학시험')
# 383 ('세부직종', '대학전공', '자격증')
# 384 ('세부직종', '어학시험', '자격증')
# 385 ('직무태그', '근무경력', '근무형태')
# 386 ('직무태그', '근무경력', '출신대학')
# 387 ('직무태그', '근무경력', '대학전공')
# 388 ('직무태그', '근무경력', '어학시험')
# 389 ('직무태그', '근무경력', '자격증')
# 390 ('직무태그', '근무형태', '출신대학')
# 391 ('직무태그', '근무형태', '대학전공')
# 392 ('직무태그', '근무형태', '어학시험')
# 393 ('직무태그', '근무형태', '자격증')
# 394 ('직무태그', '출신대학', '대학전공')
# 395 ('직무태그', '출신대학', '어학시험')
# 396 ('직무태그', '출신대학', '자격증')
# 397 ('직무태그', '대학전공', '어학시험')
# 398 ('직무태그', '대학전공', '자격증')
# 399 ('직무태그', '어학시험', '자격증')
# 400 ('근무경력', '근무형태', '출신대학')
# 401 ('근무경력', '근무형태', '대학전공')
# 402 ('근무경력', '근무형태', '어학시험')
# 403 ('근무경력', '근무형태', '자격증')
# 404 ('근무경력', '출신대학', '대학전공')
# 405 ('근무경력', '출신대학', '어학시험')
# 406 ('근무경력', '출신대학', '자격증')
# 407 ('근무경력', '대학전공', '어학시험')
# 408 ('근무경력', '대학전공', '자격증')
# 409 ('근무경력', '어학시험', '자격증')
# 410 ('근무형태', '출신대학', '대학전공')
# 411 ('근무형태', '출신대학', '어학시험')
# 412 ('근무형태', '출신대학', '자격증')
# 413 ('근무형태', '대학전공', '어학시험')
# 414 ('근무형태', '대학전공', '자격증')
# 415 ('근무형태', '어학시험', '자격증')
# 416 ('출신대학', '대학전공', '어학시험')
# 417 ('출신대학', '대학전공', '자격증')
# 418 ('출신대학', '어학시험', '자격증')
# 419 ('대학전공', '어학시험', '자격증')
# 420 ('직종', '세부직종', '근무지역_1')
# 421 ('직종', '직무태그', '근무지역_1')
# 422 ('직종', '근무경력', '근무지역_1')
# 423 ('직종', '근무형태', '근무지역_1')
# 424 ('직종', '출신대학', '근무지역_1')
# 425 ('직종', '대학전공', '근무지역_1')
# 426 ('직종', '어학시험', '근무지역_1')
# 427 ('직종', '자격증', '근무지역_1')
# 428 ('세부직종', '직무태그', '근무지역_1')
# 429 ('세부직종', '근무경력', '근무지역_1')
# 430 ('세부직종', '근무형태', '근무지역_1')
# 431 ('세부직종', '출신대학', '근무지역_1')
# 432 ('세부직종', '대학전공', '근무지역_1')
# 433 ('세부직종', '어학시험', '근무지역_1')
# 434 ('세부직종', '자격증', '근무지역_1')
# 435 ('직무태그', '근무경력', '근무지역_1')
# 436 ('직무태그', '근무형태', '근무지역_1')
# 437 ('직무태그', '출신대학', '근무지역_1')
# 438 ('직무태그', '대학전공', '근무지역_1')
# 439 ('직무태그', '어학시험', '근무지역_1')
# 440 ('직무태그', '자격증', '근무지역_1')
# 441 ('근무경력', '근무형태', '근무지역_1')
# 442 ('근무경력', '출신대학', '근무지역_1')
# 443 ('근무경력', '대학전공', '근무지역_1')
# 444 ('근무경력', '어학시험', '근무지역_1')
# 445 ('근무경력', '자격증', '근무지역_1')
# 446 ('근무형태', '출신대학', '근무지역_1')
# 447 ('근무형태', '대학전공', '근무지역_1')
# 448 ('근무형태', '어학시험', '근무지역_1')
# 449 ('근무형태', '자격증', '근무지역_1')
# 450 ('출신대학', '대학전공', '근무지역_1')
# 451 ('출신대학', '어학시험', '근무지역_1')
# 452 ('출신대학', '자격증', '근무지역_1')
# 453 ('대학전공', '어학시험', '근무지역_1')
# 454 ('대학전공', '자격증', '근무지역_1')
# 455 ('어학시험', '자격증', '근무지역_1')
# 456 ('직종', '세부직종', '근무지역_2')
# 457 ('직종', '직무태그', '근무지역_2')
# 458 ('직종', '근무경력', '근무지역_2')
# 459 ('직종', '근무형태', '근무지역_2')
# 460 ('직종', '출신대학', '근무지역_2')
# 461 ('직종', '대학전공', '근무지역_2')
# 462 ('직종', '어학시험', '근무지역_2')
# 463 ('직종', '자격증', '근무지역_2')
# 464 ('세부직종', '직무태그', '근무지역_2')
# 465 ('세부직종', '근무경력', '근무지역_2')
# 466 ('세부직종', '근무형태', '근무지역_2')
# 467 ('세부직종', '출신대학', '근무지역_2')
# 468 ('세부직종', '대학전공', '근무지역_2')
# 469 ('세부직종', '어학시험', '근무지역_2')
# 470 ('세부직종', '자격증', '근무지역_2')
# 471 ('직무태그', '근무경력', '근무지역_2')
# 472 ('직무태그', '근무형태', '근무지역_2')
# 473 ('직무태그', '출신대학', '근무지역_2')
# 474 ('직무태그', '대학전공', '근무지역_2')
# 475 ('직무태그', '어학시험', '근무지역_2')
# 476 ('직무태그', '자격증', '근무지역_2')
# 477 ('근무경력', '근무형태', '근무지역_2')
# 478 ('근무경력', '출신대학', '근무지역_2')
# 479 ('근무경력', '대학전공', '근무지역_2')
# 480 ('근무경력', '어학시험', '근무지역_2')
# 481 ('근무경력', '자격증', '근무지역_2')
# 482 ('근무형태', '출신대학', '근무지역_2')
# 483 ('근무형태', '대학전공', '근무지역_2')
# 484 ('근무형태', '어학시험', '근무지역_2')
# 485 ('근무형태', '자격증', '근무지역_2')
# 486 ('출신대학', '대학전공', '근무지역_2')
# 487 ('출신대학', '어학시험', '근무지역_2')
# 488 ('출신대학', '자격증', '근무지역_2')
# 489 ('대학전공', '어학시험', '근무지역_2')
# 490 ('대학전공', '자격증', '근무지역_2')
# 491 ('어학시험', '자격증', '근무지역_2')
# 492 ('직종', '세부직종', '근무지역_3')
# 493 ('직종', '직무태그', '근무지역_3')
# 494 ('직종', '근무경력', '근무지역_3')
# 495 ('직종', '근무형태', '근무지역_3')
# 496 ('직종', '출신대학', '근무지역_3')
# 497 ('직종', '대학전공', '근무지역_3')
# 498 ('직종', '어학시험', '근무지역_3')
# 499 ('직종', '자격증', '근무지역_3')
# 500 ('세부직종', '직무태그', '근무지역_3')
# 501 ('세부직종', '근무경력', '근무지역_3')
# 502 ('세부직종', '근무형태', '근무지역_3')
# 503 ('세부직종', '출신대학', '근무지역_3')
# 504 ('세부직종', '대학전공', '근무지역_3')
# 505 ('세부직종', '어학시험', '근무지역_3')
# 506 ('세부직종', '자격증', '근무지역_3')
# 507 ('직무태그', '근무경력', '근무지역_3')
# 508 ('직무태그', '근무형태', '근무지역_3')
# 509 ('직무태그', '출신대학', '근무지역_3')
# 510 ('직무태그', '대학전공', '근무지역_3')
# 511 ('직무태그', '어학시험', '근무지역_3')
# 512 ('직무태그', '자격증', '근무지역_3')
# 513 ('근무경력', '근무형태', '근무지역_3')
# 514 ('근무경력', '출신대학', '근무지역_3')
# 515 ('근무경력', '대학전공', '근무지역_3')
# 516 ('근무경력', '어학시험', '근무지역_3')
# 517 ('근무경력', '자격증', '근무지역_3')
# 518 ('근무형태', '출신대학', '근무지역_3')
# 519 ('근무형태', '대학전공', '근무지역_3')
# 520 ('근무형태', '어학시험', '근무지역_3')
# 521 ('근무형태', '자격증', '근무지역_3')
# 522 ('출신대학', '대학전공', '근무지역_3')
# 523 ('출신대학', '어학시험', '근무지역_3')
# 524 ('출신대학', '자격증', '근무지역_3')
# 525 ('대학전공', '어학시험', '근무지역_3')
# 526 ('대학전공', '자격증', '근무지역_3')
# 527 ('어학시험', '자격증', '근무지역_3')
# 528 직종label
# 529 세부직종label
# 530 직무태그label
# 531 근무지역label
# 532 근무경력label
# 533 출신대학label
# 534 대학전공label
# 535 어학시험label
# 536 자격증label
# 537 직종label세부직종label
# 538 직종label직무태그label
# 539 직종label근무지역label
# 540 직종label근무경력label
# 541 직종label출신대학label
# 542 직종label대학전공label
# 543 직종label어학시험label
# 544 세부직종label직무태그label
# 545 세부직종label근무지역label
# 546 세부직종label근무경력label
# 547 세부직종label출신대학label
# 548 세부직종label대학전공label
# 549 세부직종label어학시험label
# 550 직무태그label근무지역label
# 551 직무태그label근무경력label
# 552 직무태그label출신대학label
# 553 직무태그label대학전공label
# 554 직무태그label어학시험label
# 555 근무지역label근무경력label
# 556 근무지역label출신대학label
# 557 근무지역label대학전공label
# 558 근무지역label어학시험label
# 559 근무경력label출신대학label
# 560 근무경력label대학전공label
# 561 근무경력label어학시험label
# 562 출신대학label대학전공label
# 563 출신대학label어학시험label
# 564 대학전공label어학시험label
# 565 직종label세부직종label직무태그label
# 566 직종label세부직종label근무지역label
# 567 직종label세부직종label근무경력label
# 568 직종label세부직종label출신대학label
# 569 직종label세부직종label대학전공label
# 570 직종label세부직종label어학시험label
# 571 직종label직무태그label근무지역label
# 572 직종label직무태그label근무경력label
# 573 직종label직무태그label출신대학label
# 574 직종label직무태그label대학전공label
# 575 직종label직무태그label어학시험label
# 576 직종label근무지역label근무경력label
# 577 직종label근무지역label출신대학label
# 578 직종label근무지역label대학전공label
# 579 직종label근무지역label어학시험label
# 580 직종label근무경력label출신대학label
# 581 직종label근무경력label대학전공label
# 582 직종label근무경력label어학시험label
# 583 직종label출신대학label대학전공label
# 584 직종label출신대학label어학시험label
# 585 직종label대학전공label어학시험label
# 586 세부직종label직무태그label근무지역label
# 587 세부직종label직무태그label근무경력label
# 588 세부직종label직무태그label출신대학label
# 589 세부직종label직무태그label대학전공label
# 590 세부직종label직무태그label어학시험label
# 591 세부직종label근무지역label근무경력label
# 592 세부직종label근무지역label출신대학label
# 593 세부직종label근무지역label대학전공label
# 594 세부직종label근무지역label어학시험label
# 595 세부직종label근무경력label출신대학label
# 596 세부직종label근무경력label대학전공label
# 597 세부직종label근무경력label어학시험label
# 598 세부직종label출신대학label대학전공label
# 599 세부직종label출신대학label어학시험label
# 600 세부직종label대학전공label어학시험label
# 601 직무태그label근무지역label근무경력label
# 602 직무태그label근무지역label출신대학label
# 603 직무태그label근무지역label대학전공label
# 604 직무태그label근무지역label어학시험label
# 605 직무태그label근무경력label출신대학label
# 606 직무태그label근무경력label대학전공label
# 607 직무태그label근무경력label어학시험label
# 608 직무태그label출신대학label대학전공label
# 609 직무태그label출신대학label어학시험label
# 610 직무태그label대학전공label어학시험label
# 611 근무지역label근무경력label출신대학label
# 612 근무지역label근무경력label대학전공label
# 613 근무지역label근무경력label어학시험label
# 614 근무지역label출신대학label대학전공label
# 615 근무지역label출신대학label어학시험label
# 616 근무지역label대학전공label어학시험label
# 617 근무경력label출신대학label대학전공label
# 618 근무경력label출신대학label어학시험label
# 619 근무경력label대학전공label어학시험label
# 620 출신대학label대학전공label어학시험label
# 621 직종label세부직종label직무태그label근무지역label
# 622 직종label세부직종label직무태그label근무경력label
# 623 직종label세부직종label직무태그label출신대학label
# 624 직종label세부직종label직무태그label대학전공label
# 625 직종label세부직종label직무태그label어학시험label
# 626 직종label세부직종label근무지역label근무경력label
# 627 직종label세부직종label근무지역label출신대학label
# 628 직종label세부직종label근무지역label대학전공label
# 629 직종label세부직종label근무지역label어학시험label
# 630 직종label세부직종label근무경력label출신대학label
# 631 직종label세부직종label근무경력label대학전공label
# 632 직종label세부직종label근무경력label어학시험label
# 633 직종label세부직종label출신대학label대학전공label
# 634 직종label세부직종label출신대학label어학시험label
# 635 직종label세부직종label대학전공label어학시험label
# 636 직종label직무태그label근무지역label근무경력label
# 637 직종label직무태그label근무지역label출신대학label
# 638 직종label직무태그label근무지역label대학전공label
# 639 직종label직무태그label근무지역label어학시험label
# 640 직종label직무태그label근무경력label출신대학label
# 641 직종label직무태그label근무경력label대학전공label
# 642 직종label직무태그label근무경력label어학시험label
# 643 직종label직무태그label출신대학label대학전공label
# 644 직종label직무태그label출신대학label어학시험label
# 645 직종label직무태그label대학전공label어학시험label
# 646 직종label근무지역label근무경력label출신대학label
# 647 직종label근무지역label근무경력label대학전공label
# 648 직종label근무지역label근무경력label어학시험label
# 649 직종label근무지역label출신대학label대학전공label
# 650 직종label근무지역label출신대학label어학시험label
# 651 직종label근무지역label대학전공label어학시험label
# 652 직종label근무경력label출신대학label대학전공label
# 653 직종label근무경력label출신대학label어학시험label
# 654 직종label근무경력label대학전공label어학시험label
# 655 직종label출신대학label대학전공label어학시험label
# 656 세부직종label직무태그label근무지역label근무경력label
# 657 세부직종label직무태그label근무지역label출신대학label
# 658 세부직종label직무태그label근무지역label대학전공label
# 659 세부직종label직무태그label근무지역label어학시험label
# 660 세부직종label직무태그label근무경력label출신대학label
# 661 세부직종label직무태그label근무경력label대학전공label
# 662 세부직종label직무태그label근무경력label어학시험label
# 663 세부직종label직무태그label출신대학label대학전공label
# 664 세부직종label직무태그label출신대학label어학시험label
# 665 세부직종label직무태그label대학전공label어학시험label
# 666 세부직종label근무지역label근무경력label출신대학label
# 667 세부직종label근무지역label근무경력label대학전공label
# 668 세부직종label근무지역label근무경력label어학시험label
# 669 세부직종label근무지역label출신대학label대학전공label
# 670 세부직종label근무지역label출신대학label어학시험label
# 671 세부직종label근무지역label대학전공label어학시험label
# 672 세부직종label근무경력label출신대학label대학전공label
# 673 세부직종label근무경력label출신대학label어학시험label
# 674 세부직종label근무경력label대학전공label어학시험label
# 675 세부직종label출신대학label대학전공label어학시험label
# 676 직무태그label근무지역label근무경력label출신대학label
# 677 직무태그label근무지역label근무경력label대학전공label
# 678 직무태그label근무지역label근무경력label어학시험label
# 679 직무태그label근무지역label출신대학label대학전공label
# 680 직무태그label근무지역label출신대학label어학시험label
# 681 직무태그label근무지역label대학전공label어학시험label
# 682 직무태그label근무경력label출신대학label대학전공label
# 683 직무태그label근무경력label출신대학label어학시험label
# 684 직무태그label근무경력label대학전공label어학시험label
# 685 직무태그label출신대학label대학전공label어학시험label
# 686 근무지역label근무경력label출신대학label대학전공label
# 687 근무지역label근무경력label출신대학label어학시험label
# 688 근무지역label근무경력label대학전공label어학시험label
# 689 근무지역label출신대학label대학전공label어학시험label
# 690 근무경력label출신대학label대학전공label어학시험label
# 691 직종label세부직종label직무태그label근무지역label근무경력label
# 692 직종label세부직종label직무태그label근무지역label출신대학label
# 693 직종label세부직종label직무태그label근무지역label대학전공label
# 694 직종label세부직종label직무태그label근무지역label어학시험label
# 695 직종label세부직종label직무태그label근무경력label출신대학label
# 696 직종label세부직종label직무태그label근무경력label대학전공label
# 697 직종label세부직종label직무태그label근무경력label어학시험label
# 698 직종label세부직종label직무태그label출신대학label대학전공label
# 699 직종label세부직종label직무태그label출신대학label어학시험label
# 700 직종label세부직종label직무태그label대학전공label어학시험label
# 701 직종label세부직종label근무지역label근무경력label출신대학label
# 702 직종label세부직종label근무지역label근무경력label대학전공label
# 703 직종label세부직종label근무지역label근무경력label어학시험label
# 704 직종label세부직종label근무지역label출신대학label대학전공label
# 705 직종label세부직종label근무지역label출신대학label어학시험label
# 706 직종label세부직종label근무지역label대학전공label어학시험label
# 707 직종label세부직종label근무경력label출신대학label대학전공label
# 708 직종label세부직종label근무경력label출신대학label어학시험label
# 709 직종label세부직종label근무경력label대학전공label어학시험label
# 710 직종label세부직종label출신대학label대학전공label어학시험label
# 711 직종label직무태그label근무지역label근무경력label출신대학label
# 712 직종label직무태그label근무지역label근무경력label대학전공label
# 713 직종label직무태그label근무지역label근무경력label어학시험label
# 714 직종label직무태그label근무지역label출신대학label대학전공label
# 715 직종label직무태그label근무지역label출신대학label어학시험label
# 716 직종label직무태그label근무지역label대학전공label어학시험label
# 717 직종label직무태그label근무경력label출신대학label대학전공label
# 718 직종label직무태그label근무경력label출신대학label어학시험label
# 719 직종label직무태그label근무경력label대학전공label어학시험label
# 720 직종label직무태그label출신대학label대학전공label어학시험label
# 721 직종label근무지역label근무경력label출신대학label대학전공label
# 722 직종label근무지역label근무경력label출신대학label어학시험label
# 723 직종label근무지역label근무경력label대학전공label어학시험label
# 724 직종label근무지역label출신대학label대학전공label어학시험label
# 725 직종label근무경력label출신대학label대학전공label어학시험label
# 726 세부직종label직무태그label근무지역label근무경력label출신대학label
# 727 세부직종label직무태그label근무지역label근무경력label대학전공label
# 728 세부직종label직무태그label근무지역label근무경력label어학시험label
# 729 세부직종label직무태그label근무지역label출신대학label대학전공label
# 730 세부직종label직무태그label근무지역label출신대학label어학시험label
# 731 세부직종label직무태그label근무지역label대학전공label어학시험label
# 732 세부직종label직무태그label근무경력label출신대학label대학전공label
# 733 세부직종label직무태그label근무경력label출신대학label어학시험label
# 734 세부직종label직무태그label근무경력label대학전공label어학시험label
# 735 세부직종label직무태그label출신대학label대학전공label어학시험label
# 736 세부직종label근무지역label근무경력label출신대학label대학전공label
# 737 세부직종label근무지역label근무경력label출신대학label어학시험label
# 738 세부직종label근무지역label근무경력label대학전공label어학시험label
# 739 세부직종label근무지역label출신대학label대학전공label어학시험label
# 740 세부직종label근무경력label출신대학label대학전공label어학시험label
# 741 직무태그label근무지역label근무경력label출신대학label대학전공label
# 742 직무태그label근무지역label근무경력label출신대학label어학시험label
# 743 직무태그label근무지역label근무경력label대학전공label어학시험label
# 744 직무태그label근무지역label출신대학label대학전공label어학시험label
# 745 직무태그label근무경력label출신대학label대학전공label어학시험label
# 746 근무지역label근무경력label출신대학label대학전공label어학시험label
# 747 직종label세부직종label직무태그label근무지역label근무경력label출신대학label
# 748 직종label세부직종label직무태그label근무지역label근무경력label대학전공label
# 749 직종label세부직종label직무태그label근무지역label근무경력label어학시험label
# 750 직종label세부직종label직무태그label근무지역label출신대학label대학전공label
# 751 직종label세부직종label직무태그label근무지역label출신대학label어학시험label
# 752 직종label세부직종label직무태그label근무지역label대학전공label어학시험label
# 753 직종label세부직종label직무태그label근무경력label출신대학label대학전공label
# 754 직종label세부직종label직무태그label근무경력label출신대학label어학시험label
# 755 직종label세부직종label직무태그label근무경력label대학전공label어학시험label
# 756 직종label세부직종label직무태그label출신대학label대학전공label어학시험label
# 757 직종label세부직종label근무지역label근무경력label출신대학label대학전공label
# 758 직종label세부직종label근무지역label근무경력label출신대학label어학시험label
# 759 직종label세부직종label근무지역label근무경력label대학전공label어학시험label
# 760 직종label세부직종label근무지역label출신대학label대학전공label어학시험label
# 761 직종label세부직종label근무경력label출신대학label대학전공label어학시험label
# 762 직종label직무태그label근무지역label근무경력label출신대학label대학전공label
# 763 직종label직무태그label근무지역label근무경력label출신대학label어학시험label
# 764 직종label직무태그label근무지역label근무경력label대학전공label어학시험label
# 765 직종label직무태그label근무지역label출신대학label대학전공label어학시험label
# 766 직종label직무태그label근무경력label출신대학label대학전공label어학시험label
# 767 직종label근무지역label근무경력label출신대학label대학전공label어학시험label
# 768 세부직종label직무태그label근무지역label근무경력label출신대학label대학전공label
# 769 세부직종label직무태그label근무지역label근무경력label출신대학label어학시험label
# 770 세부직종label직무태그label근무지역label근무경력label대학전공label어학시험label
# 771 세부직종label직무태그label근무지역label출신대학label대학전공label어학시험label
# 772 세부직종label직무태그label근무경력label출신대학label대학전공label어학시험label
# 773 세부직종label근무지역label근무경력label출신대학label대학전공label어학시험label
# 774 직무태그label근무지역label근무경력label출신대학label대학전공label어학시험label
# 775 ('직종label세부직종label', '_log')
# 776 ('직종label직무태그label', '_log')
# 777 ('직종label근무지역label', '_log')
# 778 ('직종label근무경력label', '_log')
# 779 ('직종label출신대학label', '_log')
# 780 ('직종label대학전공label', '_log')
# 781 ('직종label어학시험label', '_log')
# 782 ('세부직종label직무태그label', '_log')
# 783 ('세부직종label근무지역label', '_log')
# 784 ('세부직종label근무경력label', '_log')
# 785 ('세부직종label출신대학label', '_log')
# 786 ('세부직종label대학전공label', '_log')
# 787 ('세부직종label어학시험label', '_log')
# 788 ('직무태그label근무지역label', '_log')
# 789 ('직무태그label근무경력label', '_log')
# 790 ('직무태그label출신대학label', '_log')
# 791 ('직무태그label대학전공label', '_log')
# 792 ('직무태그label어학시험label', '_log')
# 793 ('근무지역label근무경력label', '_log')
# 794 ('근무지역label출신대학label', '_log')
# 795 ('근무지역label대학전공label', '_log')
# 796 ('근무지역label어학시험label', '_log')
# 797 ('근무경력label출신대학label', '_log')
# 798 ('근무경력label대학전공label', '_log')
# 799 ('근무경력label어학시험label', '_log')
# 800 ('출신대학label대학전공label', '_log')
# 801 ('출신대학label어학시험label', '_log')
# 802 ('대학전공label어학시험label', '_log')
# 803 ('직종label세부직종label직무태그label', '_log')
# 804 ('직종label세부직종label근무지역label', '_log')
# 805 ('직종label세부직종label근무경력label', '_log')
# 806 ('직종label세부직종label출신대학label', '_log')
# 807 ('직종label세부직종label대학전공label', '_log')
# 808 ('직종label세부직종label어학시험label', '_log')
# 809 ('직종label직무태그label근무지역label', '_log')
# 810 ('직종label직무태그label근무경력label', '_log')
# 811 ('직종label직무태그label출신대학label', '_log')
# 812 ('직종label직무태그label대학전공label', '_log')
# 813 ('직종label직무태그label어학시험label', '_log')
# 814 ('직종label근무지역label근무경력label', '_log')
# 815 ('직종label근무지역label출신대학label', '_log')
# 816 ('직종label근무지역label대학전공label', '_log')
# 817 ('직종label근무지역label어학시험label', '_log')
# 818 ('직종label근무경력label출신대학label', '_log')
# 819 ('직종label근무경력label대학전공label', '_log')
# 820 ('직종label근무경력label어학시험label', '_log')
# 821 ('직종label출신대학label대학전공label', '_log')
# 822 ('직종label출신대학label어학시험label', '_log')
# 823 ('직종label대학전공label어학시험label', '_log')
# 824 ('세부직종label직무태그label근무지역label', '_log')
# 825 ('세부직종label직무태그label근무경력label', '_log')
# 826 ('세부직종label직무태그label출신대학label', '_log')
# 827 ('세부직종label직무태그label대학전공label', '_log')
# 828 ('세부직종label직무태그label어학시험label', '_log')
# 829 ('세부직종label근무지역label근무경력label', '_log')
# 830 ('세부직종label근무지역label출신대학label', '_log')
# 831 ('세부직종label근무지역label대학전공label', '_log')
# 832 ('세부직종label근무지역label어학시험label', '_log')
# 833 ('세부직종label근무경력label출신대학label', '_log')
# 834 ('세부직종label근무경력label대학전공label', '_log')
# 835 ('세부직종label근무경력label어학시험label', '_log')
# 836 ('세부직종label출신대학label대학전공label', '_log')
# 837 ('세부직종label출신대학label어학시험label', '_log')
# 838 ('세부직종label대학전공label어학시험label', '_log')
# 839 ('직무태그label근무지역label근무경력label', '_log')
# 840 ('직무태그label근무지역label출신대학label', '_log')
# 841 ('직무태그label근무지역label대학전공label', '_log')
# 842 ('직무태그label근무지역label어학시험label', '_log')
# 843 ('직무태그label근무경력label출신대학label', '_log')
# 844 ('직무태그label근무경력label대학전공label', '_log')
# 845 ('직무태그label근무경력label어학시험label', '_log')
# 846 ('직무태그label출신대학label대학전공label', '_log')
# 847 ('직무태그label출신대학label어학시험label', '_log')
# 848 ('직무태그label대학전공label어학시험label', '_log')
# 849 ('근무지역label근무경력label출신대학label', '_log')
# 850 ('근무지역label근무경력label대학전공label', '_log')
# 851 ('근무지역label근무경력label어학시험label', '_log')
# 852 ('근무지역label출신대학label대학전공label', '_log')
# 853 ('근무지역label출신대학label어학시험label', '_log')
# 854 ('근무지역label대학전공label어학시험label', '_log')
# 855 ('근무경력label출신대학label대학전공label', '_log')
# 856 ('근무경력label출신대학label어학시험label', '_log')
# 857 ('근무경력label대학전공label어학시험label', '_log')
# 858 ('출신대학label대학전공label어학시험label', '_log')
# 859 ('직종label세부직종label직무태그label근무지역label', '_log')
# 860 ('직종label세부직종label직무태그label근무경력label', '_log')
# 861 ('직종label세부직종label직무태그label출신대학label', '_log')
# 862 ('직종label세부직종label직무태그label대학전공label', '_log')
# 863 ('직종label세부직종label직무태그label어학시험label', '_log')
# 864 ('직종label세부직종label근무지역label근무경력label', '_log')
# 865 ('직종label세부직종label근무지역label출신대학label', '_log')
# 866 ('직종label세부직종label근무지역label대학전공label', '_log')
# 867 ('직종label세부직종label근무지역label어학시험label', '_log')
# 868 ('직종label세부직종label근무경력label출신대학label', '_log')
# 869 ('직종label세부직종label근무경력label대학전공label', '_log')
# 870 ('직종label세부직종label근무경력label어학시험label', '_log')
# 871 ('직종label세부직종label출신대학label대학전공label', '_log')
# 872 ('직종label세부직종label출신대학label어학시험label', '_log')
# 873 ('직종label세부직종label대학전공label어학시험label', '_log')
# 874 ('직종label직무태그label근무지역label근무경력label', '_log')
# 875 ('직종label직무태그label근무지역label출신대학label', '_log')
# 876 ('직종label직무태그label근무지역label대학전공label', '_log')
# 877 ('직종label직무태그label근무지역label어학시험label', '_log')
# 878 ('직종label직무태그label근무경력label출신대학label', '_log')
# 879 ('직종label직무태그label근무경력label대학전공label', '_log')
# 880 ('직종label직무태그label근무경력label어학시험label', '_log')
# 881 ('직종label직무태그label출신대학label대학전공label', '_log')
# 882 ('직종label직무태그label출신대학label어학시험label', '_log')
# 883 ('직종label직무태그label대학전공label어학시험label', '_log')
# 884 ('직종label근무지역label근무경력label출신대학label', '_log')
# 885 ('직종label근무지역label근무경력label대학전공label', '_log')
# 886 ('직종label근무지역label근무경력label어학시험label', '_log')
# 887 ('직종label근무지역label출신대학label대학전공label', '_log')
# 888 ('직종label근무지역label출신대학label어학시험label', '_log')
# 889 ('직종label근무지역label대학전공label어학시험label', '_log')
# 890 ('직종label근무경력label출신대학label대학전공label', '_log')
# 891 ('직종label근무경력label출신대학label어학시험label', '_log')
# 892 ('직종label근무경력label대학전공label어학시험label', '_log')
# 893 ('직종label출신대학label대학전공label어학시험label', '_log')
# 894 ('세부직종label직무태그label근무지역label근무경력label', '_log')
# 895 ('세부직종label직무태그label근무지역label출신대학label', '_log')
# 896 ('세부직종label직무태그label근무지역label대학전공label', '_log')
# 897 ('세부직종label직무태그label근무지역label어학시험label', '_log')
# 898 ('세부직종label직무태그label근무경력label출신대학label', '_log')
# 899 ('세부직종label직무태그label근무경력label대학전공label', '_log')
# 900 ('세부직종label직무태그label근무경력label어학시험label', '_log')
# 901 ('세부직종label직무태그label출신대학label대학전공label', '_log')
# 902 ('세부직종label직무태그label출신대학label어학시험label', '_log')
# 903 ('세부직종label직무태그label대학전공label어학시험label', '_log')
# 904 ('세부직종label근무지역label근무경력label출신대학label', '_log')
# 905 ('세부직종label근무지역label근무경력label대학전공label', '_log')
# 906 ('세부직종label근무지역label근무경력label어학시험label', '_log')
# 907 ('세부직종label근무지역label출신대학label대학전공label', '_log')
# 908 ('세부직종label근무지역label출신대학label어학시험label', '_log')
# 909 ('세부직종label근무지역label대학전공label어학시험label', '_log')
# 910 ('세부직종label근무경력label출신대학label대학전공label', '_log')
# 911 ('세부직종label근무경력label출신대학label어학시험label', '_log')
# 912 ('세부직종label근무경력label대학전공label어학시험label', '_log')
# 913 ('세부직종label출신대학label대학전공label어학시험label', '_log')
# 914 ('직무태그label근무지역label근무경력label출신대학label', '_log')
# 915 ('직무태그label근무지역label근무경력label대학전공label', '_log')
# 916 ('직무태그label근무지역label근무경력label어학시험label', '_log')
# 917 ('직무태그label근무지역label출신대학label대학전공label', '_log')
# 918 ('직무태그label근무지역label출신대학label어학시험label', '_log')
# 919 ('직무태그label근무지역label대학전공label어학시험label', '_log')
# 920 ('직무태그label근무경력label출신대학label대학전공label', '_log')
# 921 ('직무태그label근무경력label출신대학label어학시험label', '_log')
# 922 ('직무태그label근무경력label대학전공label어학시험label', '_log')
# 923 ('직무태그label출신대학label대학전공label어학시험label', '_log')
# 924 ('근무지역label근무경력label출신대학label대학전공label', '_log')
# 925 ('근무지역label근무경력label출신대학label어학시험label', '_log')
# 926 ('근무지역label근무경력label대학전공label어학시험label', '_log')
# 927 ('근무지역label출신대학label대학전공label어학시험label', '_log')
# 928 ('근무경력label출신대학label대학전공label어학시험label', '_log')
# 929 ('직종label세부직종label직무태그label근무지역label근무경력label', '_log')
# 930 ('직종label세부직종label직무태그label근무지역label출신대학label', '_log')
# 931 ('직종label세부직종label직무태그label근무지역label대학전공label', '_log')
# 932 ('직종label세부직종label직무태그label근무지역label어학시험label', '_log')
# 933 ('직종label세부직종label직무태그label근무경력label출신대학label', '_log')
# 934 ('직종label세부직종label직무태그label근무경력label대학전공label', '_log')
# 935 ('직종label세부직종label직무태그label근무경력label어학시험label', '_log')
# 936 ('직종label세부직종label직무태그label출신대학label대학전공label', '_log')
# 937 ('직종label세부직종label직무태그label출신대학label어학시험label', '_log')
# 938 ('직종label세부직종label직무태그label대학전공label어학시험label', '_log')
# 939 ('직종label세부직종label근무지역label근무경력label출신대학label', '_log')
# 940 ('직종label세부직종label근무지역label근무경력label대학전공label', '_log')
# 941 ('직종label세부직종label근무지역label근무경력label어학시험label', '_log')
# 942 ('직종label세부직종label근무지역label출신대학label대학전공label', '_log')
# 943 ('직종label세부직종label근무지역label출신대학label어학시험label', '_log')
# 944 ('직종label세부직종label근무지역label대학전공label어학시험label', '_log')
# 945 ('직종label세부직종label근무경력label출신대학label대학전공label', '_log')
# 946 ('직종label세부직종label근무경력label출신대학label어학시험label', '_log')
# 947 ('직종label세부직종label근무경력label대학전공label어학시험label', '_log')
# 948 ('직종label세부직종label출신대학label대학전공label어학시험label', '_log')
# 949 ('직종label직무태그label근무지역label근무경력label출신대학label', '_log')
# 950 ('직종label직무태그label근무지역label근무경력label대학전공label', '_log')
# 951 ('직종label직무태그label근무지역label근무경력label어학시험label', '_log')
# 952 ('직종label직무태그label근무지역label출신대학label대학전공label', '_log')
# 953 ('직종label직무태그label근무지역label출신대학label어학시험label', '_log')
# 954 ('직종label직무태그label근무지역label대학전공label어학시험label', '_log')
# 955 ('직종label직무태그label근무경력label출신대학label대학전공label', '_log')
# 956 ('직종label직무태그label근무경력label출신대학label어학시험label', '_log')
# 957 ('직종label직무태그label근무경력label대학전공label어학시험label', '_log')
# 958 ('직종label직무태그label출신대학label대학전공label어학시험label', '_log')
# 959 ('직종label근무지역label근무경력label출신대학label대학전공label', '_log')
# 960 ('직종label근무지역label근무경력label출신대학label어학시험label', '_log')
# 961 ('직종label근무지역label근무경력label대학전공label어학시험label', '_log')
# 962 ('직종label근무지역label출신대학label대학전공label어학시험label', '_log')
# 963 ('직종label근무경력label출신대학label대학전공label어학시험label', '_log')
# 964 ('세부직종label직무태그label근무지역label근무경력label출신대학label', '_log')
# 965 ('세부직종label직무태그label근무지역label근무경력label대학전공label', '_log')
# 966 ('세부직종label직무태그label근무지역label근무경력label어학시험label', '_log')
# 967 ('세부직종label직무태그label근무지역label출신대학label대학전공label', '_log')
# 968 ('세부직종label직무태그label근무지역label출신대학label어학시험label', '_log')
# 969 ('세부직종label직무태그label근무지역label대학전공label어학시험label', '_log')
# 970 ('세부직종label직무태그label근무경력label출신대학label대학전공label', '_log')
# 971 ('세부직종label직무태그label근무경력label출신대학label어학시험label', '_log')
# 972 ('세부직종label직무태그label근무경력label대학전공label어학시험label', '_log')
# 973 ('세부직종label직무태그label출신대학label대학전공label어학시험label', '_log')
# 974 ('세부직종label근무지역label근무경력label출신대학label대학전공label', '_log')
# 975 ('세부직종label근무지역label근무경력label출신대학label어학시험label', '_log')
# 976 ('세부직종label근무지역label근무경력label대학전공label어학시험label', '_log')
# 977 ('세부직종label근무지역label출신대학label대학전공label어학시험label', '_log')
# 978 ('세부직종label근무경력label출신대학label대학전공label어학시험label', '_log')
# 979 ('직무태그label근무지역label근무경력label출신대학label대학전공label', '_log')
# 980 ('직무태그label근무지역label근무경력label출신대학label어학시험label', '_log')
# 981 ('직무태그label근무지역label근무경력label대학전공label어학시험label', '_log')
# 982 ('직무태그label근무지역label출신대학label대학전공label어학시험label', '_log')
# 983 ('직무태그label근무경력label출신대학label대학전공label어학시험label', '_log')
# 984 ('근무지역label근무경력label출신대학label대학전공label어학시험label', '_log')
# 985 ('직종label세부직종label직무태그label근무지역label근무경력label출신대학label', '_log')
# 986 ('직종label세부직종label직무태그label근무지역label근무경력label대학전공label', '_log')
# 987 ('직종label세부직종label직무태그label근무지역label근무경력label어학시험label', '_log')
# 988 ('직종label세부직종label직무태그label근무지역label출신대학label대학전공label', '_log')
# 989 ('직종label세부직종label직무태그label근무지역label출신대학label어학시험label', '_log')
# 990 ('직종label세부직종label직무태그label근무지역label대학전공label어학시험label', '_log')
# 991 ('직종label세부직종label직무태그label근무경력label출신대학label대학전공label', '_log')
# 992 ('직종label세부직종label직무태그label근무경력label출신대학label어학시험label', '_log')
# 993 ('직종label세부직종label직무태그label근무경력label대학전공label어학시험label', '_log')
# 994 ('직종label세부직종label직무태그label출신대학label대학전공label어학시험label', '_log')
# 995 ('직종label세부직종label근무지역label근무경력label출신대학label대학전공label', '_log')
# 996 ('직종label세부직종label근무지역label근무경력label출신대학label어학시험label', '_log')
# 997 ('직종label세부직종label근무지역label근무경력label대학전공label어학시험label', '_log')
# 998 ('직종label세부직종label근무지역label출신대학label대학전공label어학시험label', '_log')
# 999 ('직종label세부직종label근무경력label출신대학label대학전공label어학시험label', '_log')
# 1000 ('직종label직무태그label근무지역label근무경력label출신대학label대학전공label', '_log')
# 1001 ('직종label직무태그label근무지역label근무경력label출신대학label어학시험label', '_log')
# 1002 ('직종label직무태그label근무지역label근무경력label대학전공label어학시험label', '_log')
# 1003 ('직종label직무태그label근무지역label출신대학label대학전공label어학시험label', '_log')
# 1004 ('직종label직무태그label근무경력label출신대학label대학전공label어학시험label', '_log')
# 1005 ('직종label근무지역label근무경력label출신대학label대학전공label어학시험label', '_log')
# 1006 ('세부직종label직무태그label근무지역label근무경력label출신대학label대학전공label', '_log')
# 1007 ('세부직종label직무태그label근무지역label근무경력label출신대학label어학시험label', '_log')
# 1008 ('세부직종label직무태그label근무지역label근무경력label대학전공label어학시험label', '_log')
# 1009 ('세부직종label직무태그label근무지역label출신대학label대학전공label어학시험label', '_log')
# 1010 ('세부직종label직무태그label근무경력label출신대학label대학전공label어학시험label', '_log')
# 1011 ('세부직종label근무지역label근무경력label출신대학label대학전공label어학시험label', '_log')
# 1012 ('직무태그label근무지역label근무경력label출신대학label대학전공label어학시험label', '_log')

# %%
for i in cat:
    for j in X_train.iloc[:,528:1013].columns:
        inf_num(i,j)

# %% [markdown]
# cat_com = list(combinations(cat,2))
# for i in cat_com:
#     for j in X_train.iloc[:,528:1013].columns:
#         inf_num2(i[0],i[1],j)

# %% [markdown]
# ***

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16570 entries, 0 to 16569
# Columns: 528 entries, 직종 to ('어학시험', '자격증', '근무지역_3')
# dtypes: float64(187), int64(31), object(310)
# memory usage: 66.9+ MB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11048 entries, 0 to 11047
# Columns: 528 entries, 직종 to ('어학시험', '자격증', '근무지역_3')
# dtypes: float64(187), int64(31), object(310)
# memory usage: 44.6+ MB

# %% [markdown]
# ***

# %% [markdown]
# ### csv로 저장

# %%
X_train.to_csv('X_train_fe_1124.csv',encoding='cp949', index=False)
X_test.to_csv('X_test_fe_1124.csv',encoding='cp949', index=False)
